# %%
import numpy as np
import matplotlib.pyplot as plt

from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive

# %%
file_path = "/gdrive/My Drive/BitirmeTezi/"

# %%
m1=np.loadtxt(file_path+'1.txt',dtype='float')

# %%
m1

# %%
m1.ndim

# %%
m1.min

# %%
m1.shape

# %%
np.reshape(m1,(m1.shape[0],m1.shape[1],1))

# %%
plt.set_cmap('jet')
plt.imshow(m1)
plt.imsave(file_path+"1.jpg",m1)
