# %%
! pip install librosa
! pip install mir_eval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mir_eval: filename=mir_eval-0.7-py3-none-any.whl size=100703 sha256=31e2fe1631f67e32204ea4c1a2a084ddb96ce178a70f4f6bab67a4d664b3e39a
#   Stored in directory: /root/.cache/pip/wheels/3e/2f/0d/dda9c4c77a170e21356b6afa2f7d9bb078338634ba05d94e3f
# Successfully built mir_eval
# ...

# %%
import librosa
import librosa.display as dsp
import mir_eval
from IPython.display import Audio
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
audio_path = "/gdrive/My Drive/BitirmeTezi/Animals/"
