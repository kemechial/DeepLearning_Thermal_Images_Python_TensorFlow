# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.11.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Left.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (206, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 63s 8s/step - loss: 0.1860 - accuracy: 0.2668 - val_loss: 0.1341 - val_accuracy: 0.4977
# Epoch 2/20
# 7/7 [==============================] - 2s 379ms/step - loss: 0.1140 - accuracy: 0.5033 - val_loss: 0.0966 - val_accuracy: 0.4987
# Epoch 3/20
# 7/7 [==============================] - 2s 380ms/step - loss: 0.0859 - accuracy: 0.5035 - val_loss: 0.0763 - val_accuracy: 0.4987
# Epoch 4/20
# 7/7 [==============================] - 2s 372ms/step - loss: 0.0742 - accuracy: 0.5035 - val_loss: 0.0637 - val_accuracy: 0.4987
# Epoch 5/20
# 7/7 [==============================] - 2s 379ms/step - loss: 0.0430 - accuracy: 0.5031 - val_loss: 0.0304 - val_accuracy: 0.5079
# Epoch 6/20
# 7/7 [==============================] - 2s 373ms/step - loss: 0.0253 - accuracy: 0.8748 - val_loss: 0.0175 - val_accuracy: 0.9678
# Epoch 7/20
# 7/7 [==============================] - 2s 379ms/step - loss: 0.0139 - accuracy: 0.9816 - val_loss: 0.0094 - val_accuracy: 0.9870
# Epoch 8/20
# 7/7 [==============================] - 2s 371ms/step - loss: 0.0095 - accuracy: 0.9789 - val_loss: 0.0096 - val_accuracy: 0.9709
# Epoch 9/20
# 7/7 [==============================] - 2s 380ms/step - loss: 0.0094 - accuracy: 0.9738 - val_loss: 0.0087 - val_accuracy: 0.9763
# Epoch 10/20
# 7/7 [==============================] - 2s 374ms/step - loss: 0.0086 - accuracy: 0.9787 - val_loss: 0.0080 - val_accuracy: 0.9832
# Epoch 11/20
# 7/7 [==============================] - 3s 438ms/step - loss: 0.0078 - accuracy: 0.9856 - val_loss: 0.0071 - val_accuracy: 0.9860
# Epoch 12/20
# 7/7 [==============================] - 2s 375ms/step - loss: 0.0069 - accuracy: 0.9862 - val_loss: 0.0060 - val_accuracy: 0.9845
# Epoch 13/20
# 7/7 [==============================] - 2s 378ms/step - loss: 0.0056 - accuracy: 0.9853 - val_loss: 0.0045 - val_accuracy: 0.9850
# Epoch 14/20
# 7/7 [==============================] - 2s 370ms/step - loss: 0.0041 - accuracy: 0.9853 - val_loss: 0.0032 - val_accuracy: 0.9849
# Epoch 15/20
# 7/7 [==============================] - 2s 373ms/step - loss: 0.0029 - accuracy: 0.9858 - val_loss: 0.0022 - val_accuracy: 0.9873
# Epoch 16/20
# 7/7 [==============================] - 2s 375ms/step - loss: 0.0020 - accuracy: 0.9868 - val_loss: 0.0013 - val_accuracy: 0.9860
# Epoch 17/20
# 7/7 [==============================] - 2s 375ms/step - loss: 0.0011 - accuracy: 0.9871 - val_loss: 8.1140e-04 - val_accuracy: 0.9879
# Epoch 18/20
# 7/7 [==============================] - 2s 374ms/step - loss: 7.9451e-04 - accuracy: 0.9880 - val_loss: 6.9688e-04 - val_accuracy: 0.9875
# Epoch 19/20
# 7/7 [==============================] - 2s 374ms/step - loss: 6.7902e-04 - accuracy: 0.9887 - val_loss: 6.3096e-04 - val_accuracy: 0.9894
# Epoch 20/20
# 7/7 [==============================] - 2s 368ms/step - loss: 5.9557e-04 - accuracy: 0.9888 - val_loss: 5.2674e-04 - val_accuracy: 0.9872

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v1/Left', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Left', options=load_locally)

# %%
load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Left', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([206, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 206

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[53  4]
#  [ 7 24]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.91        57
#          1.0       0.86      0.77      0.81        31
#
#     accuracy                           0.88        88
#    macro avg       0.87      0.85      0.86        88
# weighted avg       0.87      0.88      0.87        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['healthy','sick'])
disp.plot()
