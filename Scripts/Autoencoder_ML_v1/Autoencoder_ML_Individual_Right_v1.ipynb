# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.11.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Right.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (208, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 68s 9s/step - loss: 0.1757 - accuracy: 0.1152 - val_loss: 0.1157 - val_accuracy: 0.0094
# Epoch 2/20
# 7/7 [==============================] - 3s 381ms/step - loss: 0.1198 - accuracy: 0.3364 - val_loss: 0.1063 - val_accuracy: 0.5077
# Epoch 3/20
# 7/7 [==============================] - 2s 381ms/step - loss: 0.1084 - accuracy: 0.4988 - val_loss: 0.1023 - val_accuracy: 0.5098
# Epoch 4/20
# 7/7 [==============================] - 3s 383ms/step - loss: 0.1033 - accuracy: 0.5010 - val_loss: 0.0972 - val_accuracy: 0.5098
# Epoch 5/20
# 7/7 [==============================] - 3s 384ms/step - loss: 0.1001 - accuracy: 0.5008 - val_loss: 0.0961 - val_accuracy: 0.5090
# Epoch 6/20
# 7/7 [==============================] - 2s 380ms/step - loss: 0.0998 - accuracy: 0.4988 - val_loss: 0.0957 - val_accuracy: 0.5088
# Epoch 7/20
# 7/7 [==============================] - 2s 379ms/step - loss: 0.0994 - accuracy: 0.5006 - val_loss: 0.0955 - val_accuracy: 0.5098
# Epoch 8/20
# 7/7 [==============================] - 2s 378ms/step - loss: 0.0992 - accuracy: 0.5010 - val_loss: 0.0954 - val_accuracy: 0.5098
# Epoch 9/20
# 7/7 [==============================] - 3s 427ms/step - loss: 0.0991 - accuracy: 0.5010 - val_loss: 0.0953 - val_accuracy: 0.5098
# Epoch 10/20
# 7/7 [==============================] - 2s 378ms/step - loss: 0.0990 - accuracy: 0.5010 - val_loss: 0.0953 - val_accuracy: 0.5098
# Epoch 11/20
# 7/7 [==============================] - 2s 384ms/step - loss: 0.0989 - accuracy: 0.5010 - val_loss: 0.0952 - val_accuracy: 0.5098
# Epoch 12/20
# 7/7 [==============================] - 2s 377ms/step - loss: 0.0989 - accuracy: 0.5010 - val_loss: 0.0951 - val_accuracy: 0.5098
# Epoch 13/20
# 7/7 [==============================] - 2s 379ms/step - loss: 0.0988 - accuracy: 0.5010 - val_loss: 0.0951 - val_accuracy: 0.5098
# Epoch 14/20
# 7/7 [==============================] - 2s 381ms/step - loss: 0.0987 - accuracy: 0.5010 - val_loss: 0.0950 - val_accuracy: 0.5098
# Epoch 15/20
# 7/7 [==============================] - 3s 383ms/step - loss: 0.0987 - accuracy: 0.5010 - val_loss: 0.0950 - val_accuracy: 0.5098
# Epoch 16/20
# 7/7 [==============================] - 2s 381ms/step - loss: 0.0987 - accuracy: 0.5010 - val_loss: 0.0949 - val_accuracy: 0.5097
# Epoch 17/20
# 7/7 [==============================] - 2s 382ms/step - loss: 0.0986 - accuracy: 0.5009 - val_loss: 0.0949 - val_accuracy: 0.5096
# Epoch 18/20
# 7/7 [==============================] - 3s 385ms/step - loss: 0.0986 - accuracy: 0.5008 - val_loss: 0.0949 - val_accuracy: 0.5095
# Epoch 19/20
# 7/7 [==============================] - 3s 385ms/step - loss: 0.0986 - accuracy: 0.5009 - val_loss: 0.0948 - val_accuracy: 0.5097
# Epoch 20/20
# 7/7 [==============================] - 2s 376ms/step - loss: 0.0985 - accuracy: 0.5010 - val_loss: 0.0948 - val_accuracy: 0.5098

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v1/Right', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Right', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([208, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 208

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[53  4]
#  [ 8 23]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.93      0.90        57
#          1.0       0.85      0.74      0.79        31
#
#     accuracy                           0.86        88
#    macro avg       0.86      0.84      0.85        88
# weighted avg       0.86      0.86      0.86        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['healthy','sick'])
disp.plot()
