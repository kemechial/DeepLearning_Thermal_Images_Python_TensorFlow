# %%
import tensorflow as tf
import gc
import os
import numpy as np
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D, LayerNormalization
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.2-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.2
# Mounted at /gdrive
# /gdrive

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front =   tf.keras.models.load_model('/gdrive/My Drive/Model_run_v1/Frontal', options=load_locally)
    reconstructed_left=     tf.keras.models.load_model('/gdrive/My Drive/Model_run_v1/Left', options=load_locally)
    reconstructed_right =   tf.keras.models.load_model('/gdrive/My Drive/Model_run_v1/Right', options=load_locally)
    reconstructed_left45=   tf.keras.models.load_model('/gdrive/My Drive/Model_run_v1/Left45', options=load_locally)
    reconstructed_right45 = tf.keras.models.load_model('/gdrive/My Drive/Model_run_v1/Right45', options=load_locally)

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_filtered_v1/Static/Frontal.hkl")
X_train_frontal=load_hkl['xtrain'] / 255.
X_test_frontal=load_hkl['xtest'] / 255.
y_train_frontal=load_hkl['ytrain']
y_test_frontal=load_hkl['ytest']
del load_hkl
gc.collect()
# Out:
# 551

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_filtered_v1/Static/Left.hkl")
X_train_left=load_hkl['xtrain'] / 255.
X_test_left=load_hkl['xtest'] / 255.

del load_hkl
gc.collect()
# Out:
# 0

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_filtered_v1/Static/Right.hkl")
X_train_right=load_hkl['xtrain'] / 255.
X_test_right=load_hkl['xtest'] / 255.

del load_hkl
gc.collect()
# Out:
# 0

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_filtered_v1/Static/Left45.hkl")
X_train_left45=load_hkl['xtrain'] / 255.
X_test_left45=load_hkl['xtest'] / 255.

del load_hkl
gc.collect()
# Out:
# 0

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_filtered_v1/Static/Right45.hkl")
X_train_right45=load_hkl['xtrain'] / 255.
X_test_right45=load_hkl['xtest'] / 255.

del load_hkl
gc.collect()
# Out:
# 0

# %%
xm_train_frontal=reconstructed_front.encoder(X_train_frontal)
xm_test_frontal=reconstructed_front.encoder(X_test_frontal)
del X_train_frontal
del X_test_frontal
gc.collect()
# Out:
# 0

# %%
xm_train_left=reconstructed_left.encoder(X_train_left)
xm_test_left=reconstructed_left.encoder(X_test_left)
del X_train_left
del X_test_left
gc.collect()
# Out:
# 0

# %%
xm_train_right=reconstructed_right.encoder(X_train_right)
xm_test_right=reconstructed_right.encoder(X_test_right)
del X_train_right
del X_test_right
gc.collect()
# Out:
# 0

# %%
xm_train_left45=reconstructed_left45.encoder(X_train_left45)
xm_test_left45=reconstructed_left45.encoder(X_test_left45)
del X_train_left45
del X_test_left45
gc.collect()
# Out:
# 0

# %%
xm_train_right45=reconstructed_right45.encoder(X_train_right45)
xm_test_right45=reconstructed_right45.encoder(X_test_right45)
del X_train_right45
del X_test_right45
gc.collect()
# Out:
# 0

# %% [markdown]
# # **Fusion of front, left,right,left45, and right45 vectors**

# %%
class CNN_Views(Model):
    def __init__(self):
        super(CNN_Views, self).__init__()
        self.front = tf.keras.Sequential([
            layers.Input(shape=xm_train_frontal.shape[1:]),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(4, 3, strides=1, padding='same', activation='relu'),
            layers.Flatten(),
            layers.Dense(20,activation='relu'),
            layers.LayerNormalization(),
            layers.Dropout(0.1),
            layers.Dense(10,activation='relu')])

        self.left = tf.keras.Sequential([
            layers.Input(shape=xm_train_left.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(4, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(2, 3, strides=1, padding='same', activation='relu'),
            layers.Flatten(),
            layers.Dense(10,activation='relu'),
            layers.LayerNormalization(),
            layers.Dropout(0.2),
            layers.Dense(5,activation='relu')])

        self.right = tf.keras.Sequential([
            layers.Input(shape=xm_train_right.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(4, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(2, 3, strides=1, padding='same', activation='relu'),
            layers.Flatten(),
            layers.Dense(10,activation='relu'),
            layers.LayerNormalization(),
            layers.Dropout(0.3),
            layers.Dense(5,activation='relu')])

        self.left45 = tf.keras.Sequential([
            layers.Input(shape=xm_train_left45.shape[1:]),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(1, 3, strides=1, padding='same', activation='relu'),
            layers.Flatten(),
            layers.Dense(10,activation='relu'),
            layers.LayerNormalization(),
            layers.Dropout(0.3),
            layers.Dense(5, activation='relu')])

        self.right45 = tf.keras.Sequential([
            layers.Input(shape=xm_train_right45.shape[1:]),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(1, 3, strides=1, padding='same', activation='relu'),
            layers.Flatten(),
            layers.Dense(10,activation='relu'),
            layers.LayerNormalization(),
            layers.Dropout(0.3),
            layers.Dense(5, activation='relu')])

        self.combine = tf.keras.Sequential([
            layers.Input(shape=(30,)),
            layers.Dense(30, activation='relu'),
            layers.Dense(10, activation='relu'),
            layers.Dropout(0.3),
            layers.LayerNormalization(),
            layers.Dense(1, activation='sigmoid')])

    def call(self, x):
        front = self.front(x[0])
        left = self.left(x[1])
        right = self.right(x[2])
        left45 = self.left45(x[3])
        right45 = self.right45(x[4])

        out=self.combine(layers.Concatenate(axis=1)([front,left,right,left45,right45]))

        return out

# %%
import keras

# %%
cnn_combined=CNN_Views()
config=tf.keras.Sequential().from_config(cnn_combined.get_config()) # Returns pretty much every information about your model
print(config)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-39-2cb813dc69e7> in <cell line: 2>()
#       1 cnn_combined=CNN_Views()
# ----> 2 config=tf.keras.Sequential().from_config(cnn_combined.get_config()) # Returns pretty much every information about your model
#       3 print(config)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/sequential.py in from_config(cls, config, custom_objects)
#     481         if (
#     482             not model.inputs
# --> 483             and build_input_shape
#     484             and isinstance(build_input_shape, (tuple, list))
#     485         ):
#
# UnboundLocalError: local variable 'build_input_shape' referenced before assignment

# %%
keras.utils.plot_model(cnn_combined.combine, to_file='model.png',show_shapes=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-41-689b3bbaa39a> in <cell line: 1>()
# ----> 1 keras.utils.plot_model(cnn_combined.combine, to_file='model.png',show_shapes=False)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, layer_range, show_layer_activations, show_trainable)
#     485         extension = extension[1:]
#     486     # Save image to disk.
# --> 487     dot.write(to_file, format=extension)
#     488     # Return the image as a Jupyter Image object, to be displayed in-line.
#     489     # Note that we cannot easily detect whether the code is running in a
#
# /usr/local/lib/python3.10/dist-packages/pydot_ng/__init__.py in write(self, path, prog, format)
#    1753             prog = self.prog
#    1754
# -> 1755         fobj, close = get_fobj(path, 'w+b')
#    1756         try:
#    1757             if format == 'raw':
#
# /usr/local/lib/python3.10/dist-packages/pydot_ng/__init__.py in get_fobj(fname, mode)
#     134     """
#     135     if is_string_like(fname):
# --> 136         fobj = open(fname, mode)
#     137         close = True
#     138     elif hasattr(fname, 'write'):
#
# OSError: [Errno 95] Operation not supported: 'model.png'

# %% [markdown]
# ## **Deep Learning**

# %%
epochs=60

# %%
with strategy.scope():
  cnn_combined=CNN_Views()
  cnn_combined.compile(optimizer='adam',  loss='binary_crossentropy',metrics=tf.keras.metrics.BinaryAccuracy(name='binary_accuracy', dtype=None, threshold=0.5))
history=cnn_combined.fit([xm_train_frontal, xm_train_left, xm_train_right, xm_train_left45, xm_train_right45],y_train_frontal, epochs=epochs,
      batch_size=16, shuffle=True)
# Out:
# Epoch 1/60
# 13/13 [==============================] - 24s 75ms/step - loss: 0.7605 - binary_accuracy: 0.4948
# Epoch 2/60
# 13/13 [==============================] - 1s 75ms/step - loss: 0.7147 - binary_accuracy: 0.5258
# Epoch 3/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.7198 - binary_accuracy: 0.5412
# Epoch 4/60
# 13/13 [==============================] - 1s 69ms/step - loss: 0.7216 - binary_accuracy: 0.5206
# Epoch 5/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.7259 - binary_accuracy: 0.5206
# Epoch 6/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.6834 - binary_accuracy: 0.5928
# Epoch 7/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.7043 - binary_accuracy: 0.5464
# Epoch 8/60
# 13/13 [==============================] - 1s 75ms/step - loss: 0.6832 - binary_accuracy: 0.5876
# Epoch 9/60
# 13/13 [==============================] - 1s 74ms/step - loss: 0.6687 - binary_accuracy: 0.5876
# Epoch 10/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.7110 - binary_accuracy: 0.5773
# Epoch 11/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.6674 - binary_accuracy: 0.6237
# Epoch 12/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.6333 - binary_accuracy: 0.6598
# Epoch 13/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.6272 - binary_accuracy: 0.6546
# Epoch 14/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.6265 - binary_accuracy: 0.6701
# Epoch 15/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.6047 - binary_accuracy: 0.6546
# Epoch 16/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.5594 - binary_accuracy: 0.7113
# Epoch 17/60
# 13/13 [==============================] - 1s 70ms/step - loss: 0.5566 - binary_accuracy: 0.7113
# Epoch 18/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.5117 - binary_accuracy: 0.7474
# Epoch 19/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.5330 - binary_accuracy: 0.7732
# Epoch 20/60
# 13/13 [==============================] - 1s 74ms/step - loss: 0.4788 - binary_accuracy: 0.8299
# Epoch 21/60
# 13/13 [==============================] - 1s 74ms/step - loss: 0.5156 - binary_accuracy: 0.7887
# Epoch 22/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.4663 - binary_accuracy: 0.8402
# Epoch 23/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.5605 - binary_accuracy: 0.7165
# Epoch 24/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.5196 - binary_accuracy: 0.7474
# Epoch 25/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.4601 - binary_accuracy: 0.8144
# Epoch 26/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.4403 - binary_accuracy: 0.8454
# Epoch 27/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.4253 - binary_accuracy: 0.8454
# Epoch 28/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.4617 - binary_accuracy: 0.7990
# Epoch 29/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.4004 - binary_accuracy: 0.8505
# Epoch 30/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.3995 - binary_accuracy: 0.8711
# Epoch 31/60
# 13/13 [==============================] - 1s 70ms/step - loss: 0.4239 - binary_accuracy: 0.8557
# Epoch 32/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.3750 - binary_accuracy: 0.8969
# Epoch 33/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.3254 - binary_accuracy: 0.9021
# Epoch 34/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.3226 - binary_accuracy: 0.9278
# Epoch 35/60
# 13/13 [==============================] - 1s 70ms/step - loss: 0.3137 - binary_accuracy: 0.9330
# Epoch 36/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.3200 - binary_accuracy: 0.9485
# Epoch 37/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.3154 - binary_accuracy: 0.9227
# Epoch 38/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.3193 - binary_accuracy: 0.8969
# Epoch 39/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.2985 - binary_accuracy: 0.9330
# Epoch 40/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.2924 - binary_accuracy: 0.9330
# Epoch 41/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.2718 - binary_accuracy: 0.9536
# Epoch 42/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.2789 - binary_accuracy: 0.9433
# Epoch 43/60
# 13/13 [==============================] - 1s 70ms/step - loss: 0.3154 - binary_accuracy: 0.9278
# Epoch 44/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.2434 - binary_accuracy: 0.9485
# Epoch 45/60
# 13/13 [==============================] - 1s 74ms/step - loss: 0.3023 - binary_accuracy: 0.9175
# Epoch 46/60
# 13/13 [==============================] - 1s 74ms/step - loss: 0.2512 - binary_accuracy: 0.9433
# Epoch 47/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.2232 - binary_accuracy: 0.9485
# Epoch 48/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.2222 - binary_accuracy: 0.9588
# Epoch 49/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.2523 - binary_accuracy: 0.9175
# Epoch 50/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.2683 - binary_accuracy: 0.9381
# Epoch 51/60
# 13/13 [==============================] - 1s 70ms/step - loss: 0.2656 - binary_accuracy: 0.9330
# Epoch 52/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.1737 - binary_accuracy: 0.9742
# Epoch 53/60
# 13/13 [==============================] - 1s 71ms/step - loss: 0.2279 - binary_accuracy: 0.9588
# Epoch 54/60
# 13/13 [==============================] - 1s 73ms/step - loss: 0.2080 - binary_accuracy: 0.9588
# Epoch 55/60
# 13/13 [==============================] - 1s 74ms/step - loss: 0.2346 - binary_accuracy: 0.9330
# Epoch 56/60
# 13/13 [==============================] - 1s 72ms/step - loss: 0.2237 - binary_accuracy: 0.9433
# Epoch 57/60
# 13/13 [==============================] - 1s 77ms/step - loss: 0.2867 - binary_accuracy: 0.9227
# Epoch 58/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.2472 - binary_accuracy: 0.9381
# Epoch 59/60
# 13/13 [==============================] - 1s 78ms/step - loss: 0.1877 - binary_accuracy: 0.9691
# Epoch 60/60
# 13/13 [==============================] - 1s 80ms/step - loss: 0.2347 - binary_accuracy: 0.9227

# %%
#,validation_data=([xm_test_frontal, xm_test_left, xm_test_right, xm_test_left45, xm_test_right45],y_test_frontal)

# %%
cnn_combined.evaluate([xm_test_frontal, xm_test_left, xm_test_right, xm_test_left45, xm_test_right45], y_test_frontal,return_dict=True)

# %%
import seaborn as sns

# %%
y_pred=cnn_combined.predict([xm_test_frontal, xm_test_left, xm_test_right, xm_test_left45, xm_test_right45])

# %%
y_pred=np.where(y_pred > 0.5, 1,0)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,classification_report

cm=confusion_matrix(y_test_frontal, y_pred)
print(cm)
print(classification_report(y_test_frontal, y_pred))

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['0.0','1.0'])
sns.reset_orig()
disp.plot()
