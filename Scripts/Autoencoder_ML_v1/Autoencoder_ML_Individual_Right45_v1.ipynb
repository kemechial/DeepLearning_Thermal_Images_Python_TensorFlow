# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.11.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Right45.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (203, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 62s 8s/step - loss: 0.1244 - accuracy: 0.3901 - val_loss: 0.0403 - val_accuracy: 0.6484
# Epoch 2/20
# 7/7 [==============================] - 3s 385ms/step - loss: 0.0294 - accuracy: 0.6445 - val_loss: 0.0282 - val_accuracy: 0.6513
# Epoch 3/20
# 7/7 [==============================] - 2s 380ms/step - loss: 0.0219 - accuracy: 0.6459 - val_loss: 0.0201 - val_accuracy: 0.6499
# Epoch 4/20
# 7/7 [==============================] - 2s 378ms/step - loss: 0.0167 - accuracy: 0.6460 - val_loss: 0.0144 - val_accuracy: 0.6586
# Epoch 5/20
# 7/7 [==============================] - 2s 380ms/step - loss: 0.0133 - accuracy: 0.8184 - val_loss: 0.0112 - val_accuracy: 0.9504
# Epoch 6/20
# 7/7 [==============================] - 2s 375ms/step - loss: 0.0105 - accuracy: 0.9286 - val_loss: 0.0093 - val_accuracy: 0.8761
# Epoch 7/20
# 7/7 [==============================] - 2s 375ms/step - loss: 0.0090 - accuracy: 0.8801 - val_loss: 0.0081 - val_accuracy: 0.9148
# Epoch 8/20
# 7/7 [==============================] - 2s 378ms/step - loss: 0.0077 - accuracy: 0.9220 - val_loss: 0.0066 - val_accuracy: 0.9330
# Epoch 9/20
# 7/7 [==============================] - 3s 433ms/step - loss: 0.0058 - accuracy: 0.9397 - val_loss: 0.0038 - val_accuracy: 0.9566
# Epoch 10/20
# 7/7 [==============================] - 2s 373ms/step - loss: 0.0026 - accuracy: 0.9609 - val_loss: 0.0016 - val_accuracy: 0.9725
# Epoch 11/20
# 7/7 [==============================] - 2s 383ms/step - loss: 0.0014 - accuracy: 0.9788 - val_loss: 0.0012 - val_accuracy: 0.9766
# Epoch 12/20
# 7/7 [==============================] - 2s 379ms/step - loss: 0.0012 - accuracy: 0.9775 - val_loss: 0.0011 - val_accuracy: 0.9764
# Epoch 13/20
# 7/7 [==============================] - 2s 374ms/step - loss: 9.7285e-04 - accuracy: 0.9815 - val_loss: 9.1374e-04 - val_accuracy: 0.9843
# Epoch 14/20
# 7/7 [==============================] - 2s 378ms/step - loss: 8.5613e-04 - accuracy: 0.9843 - val_loss: 8.3016e-04 - val_accuracy: 0.9872
# Epoch 15/20
# 7/7 [==============================] - 2s 377ms/step - loss: 7.7859e-04 - accuracy: 0.9863 - val_loss: 7.5430e-04 - val_accuracy: 0.9867
# Epoch 16/20
# 7/7 [==============================] - 2s 372ms/step - loss: 7.1763e-04 - accuracy: 0.9872 - val_loss: 7.0779e-04 - val_accuracy: 0.9881
# Epoch 17/20
# 7/7 [==============================] - 2s 378ms/step - loss: 6.7834e-04 - accuracy: 0.9877 - val_loss: 6.6831e-04 - val_accuracy: 0.9871
# Epoch 18/20
# 7/7 [==============================] - 2s 378ms/step - loss: 6.4218e-04 - accuracy: 0.9879 - val_loss: 6.3484e-04 - val_accuracy: 0.9880
# Epoch 19/20
# 7/7 [==============================] - 2s 374ms/step - loss: 6.1217e-04 - accuracy: 0.9880 - val_loss: 6.0565e-04 - val_accuracy: 0.9888
# Epoch 20/20
# 7/7 [==============================] - 2s 373ms/step - loss: 5.8459e-04 - accuracy: 0.9887 - val_loss: 5.7810e-04 - val_accuracy: 0.9893

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Yedek/Models_Static_v1/Right45', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Yedek/Models_Static_v1/Right45', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([203, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 203

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[50  7]
#  [ 7 23]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88        57
#          1.0       0.77      0.77      0.77        30
#
#     accuracy                           0.84        87
#    macro avg       0.82      0.82      0.82        87
# weighted avg       0.84      0.84      0.84        87

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['healthy','sick'])
disp.plot()
