# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import shutil
import re
from PIL import Image
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
directory_path='/gdrive/My Drive/Yedek/Thermal_Image/Static_excluded'
save_path='/gdrive/My Drive/Yedek/Thermal_Image/Static_flipped'

# %%
def flip_image(image_path,save_path):
  original_img = Image.open(image_path)
  vertical_img = original_img.transpose(method=Image.FLIP_LEFT_RIGHT)
  vertical_img.save(save_path)
  print('image flipped!')
  original_img.close()
  vertical_img.close()

# %%
def walk_subdirectories(d_path,s_path,flip_flag=False):
   print(flip_flag)
   root,subdirectories,files=next(os.walk(d_path))
   print(f'root:{root},subdirectories:{subdirectories}, number of files: {len(files)}')
   if(len(files)==0):
      print("No files yet, keep walking...")
      for subdirectory in subdirectories:
        os.mkdir(s_path+'/'+subdirectory)
        if subdirectory in ['Left','Left45']:
           walk_subdirectories(d_path+'/'+subdirectory,s_path+'/'+subdirectory,True)
        elif flip_flag:
           walk_subdirectories(d_path+'/'+subdirectory,s_path+'/'+subdirectory,True)
        else:
          walk_subdirectories(d_path+'/'+subdirectory,s_path+'/'+subdirectory)
   else:
     for file in files:
      if flip_flag:
        flip_image(d_path+'/'+file, s_path+'/'+file)
      else:
        shutil.copy(d_path+'/'+file, s_path+'/'+file)

# %% [markdown]
# # **Initiate Recursion**

# %%
walk_subdirectories(directory_path,save_path)
# Out:
# False
# root:/gdrive/My Drive/Yedek/Thermal_Image/Static,subdirectories:['Frontal', 'Right45', 'Right', 'Left45', 'Left'], number of files: 0
# No files yet, keep walking...
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-5-3e069a066ee4> in <cell line: 1>()
# ----> 1 walk_subdirectories(directory_path,save_path)
#
# <ipython-input-4-5876ad3648bf> in walk_subdirectories(d_path, s_path, flip_flag)
#       6       print("No files yet, keep walking...")
#       7       for subdirectory in subdirectories:
# ----> 8         os.mkdir(s_path+'/'+subdirectory)
#       9         if subdirectory in ['Left','Left45']:
#      10            walk_subdirectories(d_path+'/'+subdirectory,s_path+'/'+subdirectory,True)
#
# FileExistsError: [Errno 17] File exists: '/gdrive/My Drive/Yedek/Thermal_Image/Static_flipped/Frontal'
