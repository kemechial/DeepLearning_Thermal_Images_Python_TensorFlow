# %%
import re

# %%
test="T0191.1.1.S.2013-09-06.00.txt"
re.split('[A-Z]',test.split(".")[0])[1]
# Out:
# '0191'

# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !ls "/gdrive/My Drive/Yedek/Autoencoder_Datasets_flipped/Static/"
# Out:
# ls: cannot access '/gdrive/My Drive/Yedek/Autoencoder_Datasets_flipped/Static/': No such file or directory
