# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Requirement already satisfied: hickle in /usr/local/lib/python3.10/dist-packages (5.0.2)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v2/Static/Frontal.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (176, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(4, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(1, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(1, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(4, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='sigmoid')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=16, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 11/11 [==============================] - 22s 1s/step - loss: 0.0517 - accuracy: 0.6575 - val_loss: 0.0435 - val_accuracy: 0.6920
# Epoch 2/40
# 11/11 [==============================] - 2s 234ms/step - loss: 0.0408 - accuracy: 0.6904 - val_loss: 0.0368 - val_accuracy: 0.6919
# Epoch 3/40
# 11/11 [==============================] - 3s 241ms/step - loss: 0.0380 - accuracy: 0.6900 - val_loss: 0.0357 - val_accuracy: 0.6914
# Epoch 4/40
# 11/11 [==============================] - 3s 241ms/step - loss: 0.0365 - accuracy: 0.6900 - val_loss: 0.0338 - val_accuracy: 0.6925
# Epoch 5/40
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0331 - accuracy: 0.6932 - val_loss: 0.0282 - val_accuracy: 0.7035
# Epoch 6/40
# 11/11 [==============================] - 3s 255ms/step - loss: 0.0257 - accuracy: 0.8389 - val_loss: 0.0195 - val_accuracy: 0.9099
# Epoch 7/40
# 11/11 [==============================] - 2s 236ms/step - loss: 0.0180 - accuracy: 0.9189 - val_loss: 0.0142 - val_accuracy: 0.9367
# Epoch 8/40
# 11/11 [==============================] - 2s 231ms/step - loss: 0.0138 - accuracy: 0.9423 - val_loss: 0.0115 - val_accuracy: 0.9511
# Epoch 9/40
# 11/11 [==============================] - 2s 232ms/step - loss: 0.0114 - accuracy: 0.9480 - val_loss: 0.0102 - val_accuracy: 0.9307
# Epoch 10/40
# 11/11 [==============================] - 2s 235ms/step - loss: 0.0102 - accuracy: 0.9378 - val_loss: 0.0094 - val_accuracy: 0.9358
# Epoch 11/40
# 11/11 [==============================] - 3s 253ms/step - loss: 0.0095 - accuracy: 0.9432 - val_loss: 0.0089 - val_accuracy: 0.9506
# Epoch 12/40
# 11/11 [==============================] - 3s 244ms/step - loss: 0.0089 - accuracy: 0.9494 - val_loss: 0.0085 - val_accuracy: 0.9531
# Epoch 13/40
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0084 - accuracy: 0.9549 - val_loss: 0.0082 - val_accuracy: 0.9624
# Epoch 14/40
# 11/11 [==============================] - 2s 232ms/step - loss: 0.0080 - accuracy: 0.9590 - val_loss: 0.0075 - val_accuracy: 0.9621
# Epoch 15/40
# 11/11 [==============================] - 3s 241ms/step - loss: 0.0072 - accuracy: 0.9613 - val_loss: 0.0066 - val_accuracy: 0.9636
# Epoch 16/40
# 11/11 [==============================] - 3s 255ms/step - loss: 0.0061 - accuracy: 0.9624 - val_loss: 0.0055 - val_accuracy: 0.9632
# Epoch 17/40
# 11/11 [==============================] - 3s 244ms/step - loss: 0.0052 - accuracy: 0.9593 - val_loss: 0.0047 - val_accuracy: 0.9581
# Epoch 18/40
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0047 - accuracy: 0.9558 - val_loss: 0.0043 - val_accuracy: 0.9530
# Epoch 19/40
# 11/11 [==============================] - 3s 242ms/step - loss: 0.0041 - accuracy: 0.9538 - val_loss: 0.0038 - val_accuracy: 0.9589
# Epoch 20/40
# 11/11 [==============================] - 3s 243ms/step - loss: 0.0037 - accuracy: 0.9513 - val_loss: 0.0035 - val_accuracy: 0.9533
# Epoch 21/40
# 11/11 [==============================] - 3s 336ms/step - loss: 0.0034 - accuracy: 0.9496 - val_loss: 0.0032 - val_accuracy: 0.9481
# Epoch 22/40
# 11/11 [==============================] - 3s 246ms/step - loss: 0.0031 - accuracy: 0.9540 - val_loss: 0.0030 - val_accuracy: 0.9595
# Epoch 23/40
# 11/11 [==============================] - 3s 236ms/step - loss: 0.0029 - accuracy: 0.9589 - val_loss: 0.0029 - val_accuracy: 0.9560
# Epoch 24/40
# 11/11 [==============================] - 3s 236ms/step - loss: 0.0028 - accuracy: 0.9609 - val_loss: 0.0027 - val_accuracy: 0.9623
# Epoch 25/40
# 11/11 [==============================] - 3s 256ms/step - loss: 0.0027 - accuracy: 0.9630 - val_loss: 0.0026 - val_accuracy: 0.9647
# Epoch 26/40
# 11/11 [==============================] - 2s 235ms/step - loss: 0.0026 - accuracy: 0.9641 - val_loss: 0.0026 - val_accuracy: 0.9649
# Epoch 27/40
# 11/11 [==============================] - 2s 234ms/step - loss: 0.0025 - accuracy: 0.9645 - val_loss: 0.0025 - val_accuracy: 0.9653
# Epoch 28/40
# 11/11 [==============================] - 2s 235ms/step - loss: 0.0025 - accuracy: 0.9644 - val_loss: 0.0025 - val_accuracy: 0.9647
# Epoch 29/40
# 11/11 [==============================] - 2s 233ms/step - loss: 0.0024 - accuracy: 0.9644 - val_loss: 0.0024 - val_accuracy: 0.9659
# Epoch 30/40
# 11/11 [==============================] - 3s 250ms/step - loss: 0.0024 - accuracy: 0.9655 - val_loss: 0.0024 - val_accuracy: 0.9672
# Epoch 31/40
# 11/11 [==============================] - 2s 233ms/step - loss: 0.0023 - accuracy: 0.9657 - val_loss: 0.0023 - val_accuracy: 0.9672
# Epoch 32/40
# 11/11 [==============================] - 3s 241ms/step - loss: 0.0023 - accuracy: 0.9661 - val_loss: 0.0024 - val_accuracy: 0.9661
# Epoch 33/40
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0023 - accuracy: 0.9655 - val_loss: 0.0023 - val_accuracy: 0.9677
# Epoch 34/40
# 11/11 [==============================] - 3s 236ms/step - loss: 0.0023 - accuracy: 0.9663 - val_loss: 0.0024 - val_accuracy: 0.9670
# Epoch 35/40
# 11/11 [==============================] - 3s 254ms/step - loss: 0.0023 - accuracy: 0.9662 - val_loss: 0.0022 - val_accuracy: 0.9673
# Epoch 36/40
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0022 - accuracy: 0.9662 - val_loss: 0.0022 - val_accuracy: 0.9681
# Epoch 37/40
# 11/11 [==============================] - 3s 237ms/step - loss: 0.0022 - accuracy: 0.9669 - val_loss: 0.0022 - val_accuracy: 0.9681
# Epoch 38/40
# 11/11 [==============================] - 3s 238ms/step - loss: 0.0021 - accuracy: 0.9670 - val_loss: 0.0021 - val_accuracy: 0.9685
# Epoch 39/40
# 11/11 [==============================] - 3s 249ms/step - loss: 0.0021 - accuracy: 0.9671 - val_loss: 0.0021 - val_accuracy: 0.9687
# Epoch 40/40
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0021 - accuracy: 0.9675 - val_loss: 0.0021 - val_accuracy: 0.9688

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v2/Frontal', options=save_locally)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 10). These functions will not be directly callable after loading.

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v2/Frontal', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([176, 60, 80, 1])

# %%
xm_train.shape[0]
# Out:
# 176

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[47  4]
#  [ 5 19]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.92      0.91        51
#          1.0       0.83      0.79      0.81        24
#
#     accuracy                           0.88        75
#    macro avg       0.86      0.86      0.86        75
# weighted avg       0.88      0.88      0.88        75

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
