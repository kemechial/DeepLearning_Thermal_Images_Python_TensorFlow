# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# WARNING:tensorflow:TPU system grpc://10.124.158.138:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Requirement already satisfied: hickle in /usr/local/lib/python3.10/dist-packages (5.0.2)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v2/Static/Frontal.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (176, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=30

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=16, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/30
# 11/11 [==============================] - 28s 1s/step - loss: 0.1337 - accuracy: 0.6938 - val_loss: 0.0735 - val_accuracy: 0.7015
# Epoch 2/30
# 11/11 [==============================] - 2s 227ms/step - loss: 0.0652 - accuracy: 0.7171 - val_loss: 0.0393 - val_accuracy: 0.9470
# Epoch 3/30
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0263 - accuracy: 0.9408 - val_loss: 0.0187 - val_accuracy: 0.9119
# Epoch 4/30
# 11/11 [==============================] - 2s 232ms/step - loss: 0.0146 - accuracy: 0.9387 - val_loss: 0.0082 - val_accuracy: 0.9704
# Epoch 5/30
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0070 - accuracy: 0.9701 - val_loss: 0.0044 - val_accuracy: 0.9765
# Epoch 6/30
# 11/11 [==============================] - 2s 217ms/step - loss: 0.0036 - accuracy: 0.9723 - val_loss: 0.0027 - val_accuracy: 0.9675
# Epoch 7/30
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0023 - accuracy: 0.9714 - val_loss: 0.0019 - val_accuracy: 0.9751
# Epoch 8/30
# 11/11 [==============================] - 2s 219ms/step - loss: 0.0018 - accuracy: 0.9760 - val_loss: 0.0016 - val_accuracy: 0.9771
# Epoch 9/30
# 11/11 [==============================] - 2s 228ms/step - loss: 0.0015 - accuracy: 0.9769 - val_loss: 0.0014 - val_accuracy: 0.9774
# Epoch 10/30
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0013 - accuracy: 0.9782 - val_loss: 0.0013 - val_accuracy: 0.9786
# Epoch 11/30
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0011 - accuracy: 0.9776 - val_loss: 0.0011 - val_accuracy: 0.9790
# Epoch 12/30
# 11/11 [==============================] - 2s 218ms/step - loss: 9.6520e-04 - accuracy: 0.9781 - val_loss: 9.3106e-04 - val_accuracy: 0.9793
# Epoch 13/30
# 11/11 [==============================] - 2s 217ms/step - loss: 8.6150e-04 - accuracy: 0.9798 - val_loss: 8.4848e-04 - val_accuracy: 0.9811
# Epoch 14/30
# 11/11 [==============================] - 2s 229ms/step - loss: 7.6884e-04 - accuracy: 0.9810 - val_loss: 7.3715e-04 - val_accuracy: 0.9819
# Epoch 15/30
# 11/11 [==============================] - 2s 214ms/step - loss: 6.8097e-04 - accuracy: 0.9829 - val_loss: 6.7698e-04 - val_accuracy: 0.9845
# Epoch 16/30
# 11/11 [==============================] - 3s 263ms/step - loss: 6.1648e-04 - accuracy: 0.9848 - val_loss: 6.0515e-04 - val_accuracy: 0.9857
# Epoch 17/30
# 11/11 [==============================] - 2s 215ms/step - loss: 5.6327e-04 - accuracy: 0.9852 - val_loss: 5.5787e-04 - val_accuracy: 0.9859
# Epoch 18/30
# 11/11 [==============================] - 2s 216ms/step - loss: 5.2378e-04 - accuracy: 0.9858 - val_loss: 5.2643e-04 - val_accuracy: 0.9859
# Epoch 19/30
# 11/11 [==============================] - 2s 228ms/step - loss: 4.8887e-04 - accuracy: 0.9861 - val_loss: 4.9230e-04 - val_accuracy: 0.9852
# Epoch 20/30
# 11/11 [==============================] - 2s 213ms/step - loss: 4.6557e-04 - accuracy: 0.9859 - val_loss: 4.6532e-04 - val_accuracy: 0.9867
# Epoch 21/30
# 11/11 [==============================] - 3s 336ms/step - loss: 4.7207e-04 - accuracy: 0.9852 - val_loss: 4.5627e-04 - val_accuracy: 0.9870
# Epoch 22/30
# 11/11 [==============================] - 3s 324ms/step - loss: 5.5148e-04 - accuracy: 0.9819 - val_loss: 4.6827e-04 - val_accuracy: 0.9834
# Epoch 23/30
# 11/11 [==============================] - 3s 253ms/step - loss: 4.8428e-04 - accuracy: 0.9844 - val_loss: 4.7086e-04 - val_accuracy: 0.9878
# Epoch 24/30
# 11/11 [==============================] - 2s 230ms/step - loss: 4.1275e-04 - accuracy: 0.9869 - val_loss: 4.0070e-04 - val_accuracy: 0.9870
# Epoch 25/30
# 11/11 [==============================] - 2s 212ms/step - loss: 3.7955e-04 - accuracy: 0.9873 - val_loss: 3.9543e-04 - val_accuracy: 0.9862
# Epoch 26/30
# 11/11 [==============================] - 2s 215ms/step - loss: 3.6973e-04 - accuracy: 0.9869 - val_loss: 3.7569e-04 - val_accuracy: 0.9879
# Epoch 27/30
# 11/11 [==============================] - 2s 214ms/step - loss: 3.5466e-04 - accuracy: 0.9873 - val_loss: 3.5865e-04 - val_accuracy: 0.9881
# Epoch 28/30
# 11/11 [==============================] - 2s 214ms/step - loss: 3.4221e-04 - accuracy: 0.9874 - val_loss: 3.6076e-04 - val_accuracy: 0.9868
# Epoch 29/30
# 11/11 [==============================] - 2s 229ms/step - loss: 3.3392e-04 - accuracy: 0.9877 - val_loss: 3.4839e-04 - val_accuracy: 0.9885
# Epoch 30/30
# 11/11 [==============================] - 2s 223ms/step - loss: 3.3023e-04 - accuracy: 0.9878 - val_loss: 3.3617e-04 - val_accuracy: 0.9881

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v2/Frontal', options=save_locally)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v2/Frontal', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([176, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 176

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[46  5]
#  [ 4 20]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.90      0.91        51
#          1.0       0.80      0.83      0.82        24
#
#     accuracy                           0.88        75
#    macro avg       0.86      0.87      0.86        75
# weighted avg       0.88      0.88      0.88        75

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
