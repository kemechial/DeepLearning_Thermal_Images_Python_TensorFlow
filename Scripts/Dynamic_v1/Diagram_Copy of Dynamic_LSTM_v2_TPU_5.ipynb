# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
directory_path='/gdrive/My Drive/Yedek/Video_Dataset_hsv'

# %%
subset_paths={'train':directory_path+'/train','test':directory_path+'/test'}

# %%
# !pip install hickle
import hickle as hkl
import random
from pathlib import Path
import os
import cv2
import matplotlib.pyplot as plt
from random import randint
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3

# %%
def frames_from_video_file(video_path):
  result = []
  src = cv2.VideoCapture(str(video_path))

  for _ in range(0,20,2):
    ret, frame = src.read()
    frame = tf.image.convert_image_dtype(frame, tf.float32)
    tf.image.resize(frame, [456,456])
    result.append(frame)
  src.release()
  result = np.array(result)[..., [2, 1, 0]]
  return result

# %%
class FrameGenerator:
  def __init__(self, path, training = False):

    self.path = path
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.avi'))
    classes = [p.parent.name for p in video_paths]
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path)
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %%
train_path = Path(subset_paths['train'])
test_path = Path(subset_paths['test'])

# %%
fg = FrameGenerator(train_path, training=True)
print(fg.class_ids_for_name)
# Out:
# {'healthy': 0, 'sick': 1}

# %%
output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.float32))

# %%
train_ds = tf.data.Dataset.from_generator(FrameGenerator(train_path, training=True),
                                          output_signature = output_signature)
test_ds = tf.data.Dataset.from_generator(FrameGenerator(test_path, training=False),
                                          output_signature = output_signature)

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
train_ds = train_ds.batch(16)
test_ds = test_ds.batch(16)

train_frames, train_labels = next(iter(train_ds))
print(f'Shape of training set of frames: {train_frames.shape}')
print(f'Shape of training labels: {train_labels.shape}')

test_frames, test_labels = next(iter(test_ds))
print(f'Shape of validation set of frames: {test_frames.shape}')
print(f'Shape of validation labels: {test_labels.shape}')
# Out:
# Shape of training set of frames: (16, 10, 480, 640, 3)
# Shape of training labels: (16,)
# Shape of validation set of frames: (16, 10, 480, 640, 3)
# Shape of validation labels: (16,)

# %%
def build_efficient():
    inputs = tf.keras.layers.Input(shape=(456, 456, 3))
    model = tf.keras.applications.EfficientNetB5(include_top=False, input_tensor=inputs, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    model = tf.keras.Sequential([model,tf.keras.layers.GlobalAveragePooling2D(),tf.keras.layers.BatchNormalization()])

    return model

# %%
net=build_efficient()
net.build()
keras.utils.plot_model(
    net,
    to_file="/gdrive/My Drive/model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=100,
    show_layer_activations=False,
    show_trainable=False
)
IPython.display.Image("/gdrive/My Drive/model.png")

# %%
import keras

import IPython

net=build_efficient()
model = tf.keras.Sequential([
      tf.keras.layers.Rescaling(scale=255),
      tf.keras.layers.TimeDistributed(net),
      tf.keras.layers.LSTM(24),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(8),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(4),
      tf.keras.layers.Dense(1,'sigmoid')
  ])

model.build((None,10, 456, 456, 3))

keras.utils.plot_model(
    model,
    to_file="/gdrive/My Drive/model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=100,
    show_layer_activations=False,
    show_trainable=False
)
IPython.display.Image("/gdrive/My Drive/model.png")

# %%
net=build_efficient()

model = tf.keras.Sequential([
      tf.keras.layers.Rescaling(scale=255),
      tf.keras.layers.TimeDistributed(net),
      tf.keras.layers.LSTM(24),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(8),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(4),
      tf.keras.layers.Dense(1,'sigmoid')
  ])

model.compile(optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3,  use_ema=True, ema_momentum = 0.8, weight_decay=0.1),
                loss='mse', metrics=tf.keras.metrics.BinaryAccuracy(name='binary_accuracy', dtype=None, threshold=0.5))

keras.utils.plot_model(
    model,
    to_file="/gdrive/My Drive/model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=100,
    show_layer_activations=False,
    show_trainable=False
)
IPython.display.Image("/gdrive/My Drive/model.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-001e03aaf226> in <cell line: 1>()
# ----> 1 net=build_efficient()
#       2
#       3 model = tf.keras.Sequential([
#       4       tf.keras.layers.Rescaling(scale=255),
#       5       tf.keras.layers.TimeDistributed(net),
#
# <ipython-input-29-88e5e9ee3add> in build_efficient()
#       3 import IPython
#       4 def build_efficient():
# ----> 5     return tf.keras.applications.EfficientNetB5(input_shape=(None,456, 456, 3), include_top=False)
#       6
#       7 net=build_efficient()
#
# /usr/local/lib/python3.10/dist-packages/keras/src/applications/efficientnet.py in EfficientNetB5(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation, **kwargs)
#     753     **kwargs,
#     754 ):
# --> 755     return EfficientNet(
#     756         1.6,
#     757         2.2,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/applications/efficientnet.py in EfficientNet(width_coefficient, depth_coefficient, default_size, dropout_rate, drop_connect_rate, depth_divisor, activation, blocks_args, model_name, include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     319
#     320     # Determine proper input shape
# --> 321     input_shape = imagenet_utils.obtain_input_shape(
#     322         input_shape,
#     323         default_size=default_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/applications/imagenet_utils.py in obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     396             if input_shape is not None:
#     397                 if len(input_shape) != 3:
# --> 398                     raise ValueError(
#     399                         "`input_shape` must be a tuple of three integers."
#     400                     )
#
# ValueError: `input_shape` must be a tuple of three integers.

# %%
epochs=40

# %%
model.fit(train_ds, epochs = epochs)
# Out:
# Epoch 1/40
# 11/11 [==============================] - 81s 844ms/step - loss: 0.2378 - binary_accuracy: 0.5795
# Epoch 2/40
# 11/11 [==============================] - 9s 836ms/step - loss: 0.2061 - binary_accuracy: 0.6818
# Epoch 3/40
# 11/11 [==============================] - 9s 844ms/step - loss: 0.1700 - binary_accuracy: 0.7727
# Epoch 4/40
# 11/11 [==============================] - 9s 834ms/step - loss: 0.1533 - binary_accuracy: 0.7955
# Epoch 5/40
# 11/11 [==============================] - 9s 839ms/step - loss: 0.1556 - binary_accuracy: 0.7841
# Epoch 6/40
# 11/11 [==============================] - 10s 855ms/step - loss: 0.1521 - binary_accuracy: 0.7955
# Epoch 7/40
# 11/11 [==============================] - 10s 857ms/step - loss: 0.1543 - binary_accuracy: 0.7841
# Epoch 8/40
# 11/11 [==============================] - 9s 842ms/step - loss: 0.1341 - binary_accuracy: 0.8239
# Epoch 9/40
# 11/11 [==============================] - 9s 839ms/step - loss: 0.1160 - binary_accuracy: 0.8580
# Epoch 10/40
# 11/11 [==============================] - 9s 838ms/step - loss: 0.1254 - binary_accuracy: 0.8580
# Epoch 11/40
# 11/11 [==============================] - 9s 828ms/step - loss: 0.1147 - binary_accuracy: 0.8409
# Epoch 12/40
# 11/11 [==============================] - 9s 834ms/step - loss: 0.1262 - binary_accuracy: 0.8352
# Epoch 13/40
# 11/11 [==============================] - 10s 862ms/step - loss: 0.1144 - binary_accuracy: 0.8693
# Epoch 14/40
# 11/11 [==============================] - 9s 838ms/step - loss: 0.1051 - binary_accuracy: 0.8580
# Epoch 15/40
# 11/11 [==============================] - 9s 812ms/step - loss: 0.1098 - binary_accuracy: 0.8466
# Epoch 16/40
# 11/11 [==============================] - 9s 843ms/step - loss: 0.0990 - binary_accuracy: 0.8693
# Epoch 17/40
# 11/11 [==============================] - 9s 816ms/step - loss: 0.0853 - binary_accuracy: 0.8807
# Epoch 18/40
# 11/11 [==============================] - 10s 844ms/step - loss: 0.1100 - binary_accuracy: 0.8580
# Epoch 19/40
# 11/11 [==============================] - 10s 849ms/step - loss: 0.0945 - binary_accuracy: 0.8920
# Epoch 20/40
# 11/11 [==============================] - 10s 843ms/step - loss: 0.0882 - binary_accuracy: 0.9034
# Epoch 21/40
# 11/11 [==============================] - 9s 827ms/step - loss: 0.0839 - binary_accuracy: 0.9034
# Epoch 22/40
# 11/11 [==============================] - 9s 827ms/step - loss: 0.0832 - binary_accuracy: 0.8807
# Epoch 23/40
# 11/11 [==============================] - 10s 853ms/step - loss: 0.0737 - binary_accuracy: 0.9261
# Epoch 24/40
# 11/11 [==============================] - 10s 853ms/step - loss: 0.0746 - binary_accuracy: 0.9091
# Epoch 25/40
# 11/11 [==============================] - 10s 861ms/step - loss: 0.0537 - binary_accuracy: 0.9375
# Epoch 26/40
# 11/11 [==============================] - 9s 833ms/step - loss: 0.0615 - binary_accuracy: 0.9318
# Epoch 27/40
# 11/11 [==============================] - 9s 843ms/step - loss: 0.0699 - binary_accuracy: 0.9091
# Epoch 28/40
# 11/11 [==============================] - 9s 842ms/step - loss: 0.0796 - binary_accuracy: 0.8693
# Epoch 29/40
# 11/11 [==============================] - 9s 832ms/step - loss: 0.0636 - binary_accuracy: 0.8920
# Epoch 30/40
# 11/11 [==============================] - 9s 828ms/step - loss: 0.0698 - binary_accuracy: 0.8977
# Epoch 31/40
# 11/11 [==============================] - 9s 843ms/step - loss: 0.0523 - binary_accuracy: 0.9148
# Epoch 32/40
# 11/11 [==============================] - 9s 836ms/step - loss: 0.0604 - binary_accuracy: 0.9375
# Epoch 33/40
# 11/11 [==============================] - 10s 852ms/step - loss: 0.0540 - binary_accuracy: 0.9318
# Epoch 34/40
# 11/11 [==============================] - 9s 832ms/step - loss: 0.0788 - binary_accuracy: 0.8693
# Epoch 35/40
# 11/11 [==============================] - 9s 840ms/step - loss: 0.0647 - binary_accuracy: 0.9148
# Epoch 36/40
# 11/11 [==============================] - 9s 837ms/step - loss: 0.0496 - binary_accuracy: 0.9375
# Epoch 37/40
# 11/11 [==============================] - 10s 858ms/step - loss: 0.0528 - binary_accuracy: 0.9318
# Epoch 38/40
# 11/11 [==============================] - 9s 841ms/step - loss: 0.0706 - binary_accuracy: 0.9034
# Epoch 39/40
# 11/11 [==============================] - 10s 849ms/step - loss: 0.0617 - binary_accuracy: 0.9148
# Epoch 40/40
# 11/11 [==============================] - 9s 841ms/step - loss: 0.0474 - binary_accuracy: 0.9318

# %%
def get_actual_labels(dataset):
  actual = [labels for _, labels in dataset.unbatch()]
  actual = tf.stack(actual, axis=0)
  return actual

# %%
model.evaluate(test_ds ,return_dict=True)
# Out:
# 5/5 [==============================] - 54s 5s/step - loss: 0.1289 - binary_accuracy: 0.8158
# {'loss': 0.12887871265411377, 'binary_accuracy': 0.8157894611358643}

# %%
import seaborn as sns

# %%
actual = get_actual_labels(test_ds)

# %%
y_pred=model.predict(test_ds)
y_pred=np.where(y_pred > 0.5, 1,0)
# Out:
# 5/5 [==============================] - 36s 780ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,classification_report

cm=confusion_matrix(actual, y_pred)
print(cm)
print(classification_report(actual, y_pred))
# Out:
# [[40  8]
#  [ 6 22]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.83      0.85        48
#          1.0       0.73      0.79      0.76        28
#
#     accuracy                           0.82        76
#    macro avg       0.80      0.81      0.80        76
# weighted avg       0.82      0.82      0.82        76

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['healthy','sick'])
sns.reset_orig()
disp.plot()
