# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import re
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
directory_path='/gdrive/My Drive/Yedek/Thermal_Image/Static_excluded'

# %%
files=['image_2_1.jpg','image_4_1.jpg','image_5_1.jpg','image_6_1.jpg','image_7_1.jpg']

# %%
directories=['Frontal/healthy', 'Right45/healthy', 'Right/healthy', 'Left45/healthy', 'Left/healthy']

# %%
file_paths=[]

# %%
 file=files[0]
 for directory in directories:
      file_paths.append(directory_path+'/'+directory+'/'+file)

# %%
print(file_paths)
# Out:
# ['/gdrive/My Drive/Yedek/Thermal_Image/Static_excluded/Frontal/healthy/image_2_1.jpg', '/gdrive/My Drive/Yedek/Thermal_Image/Static_excluded/Right45/healthy/image_2_1.jpg', '/gdrive/My Drive/Yedek/Thermal_Image/Static_excluded/Right/healthy/image_2_1.jpg', '/gdrive/My Drive/Yedek/Thermal_Image/Static_excluded/Left45/healthy/image_2_1.jpg', '/gdrive/My Drive/Yedek/Thermal_Image/Static_excluded/Left/healthy/image_2_1.jpg']

# %%
plt.figure(figsize=(10, 10))
plt.set_cmap('viridis')
for i in range(0,5):
      print(i)
      ax = plt.subplot(1, 5, i+ 1)
      img = mpimg.imread(file_paths[i])
      plt.imshow(img)
      plt.axis("off")
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(file_paths[0])
