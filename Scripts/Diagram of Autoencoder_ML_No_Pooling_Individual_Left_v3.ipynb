# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.10.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Left.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (206, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 7/7 [==============================] - 59s 7s/step - loss: 0.1902 - accuracy: 0.3317 - val_loss: 0.1750 - val_accuracy: 0.3494
# Epoch 2/40
# 7/7 [==============================] - 2s 283ms/step - loss: 0.1554 - accuracy: 0.3499 - val_loss: 0.1126 - val_accuracy: 0.3571
# Epoch 3/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.1031 - accuracy: 0.3597 - val_loss: 0.0847 - val_accuracy: 0.3888
# Epoch 4/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0736 - accuracy: 0.4078 - val_loss: 0.0608 - val_accuracy: 0.4216
# Epoch 5/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0531 - accuracy: 0.4389 - val_loss: 0.0446 - val_accuracy: 0.4478
# Epoch 6/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0400 - accuracy: 0.4703 - val_loss: 0.0346 - val_accuracy: 0.4848
# Epoch 7/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0327 - accuracy: 0.4953 - val_loss: 0.0300 - val_accuracy: 0.4939
# Epoch 8/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0289 - accuracy: 0.5071 - val_loss: 0.0273 - val_accuracy: 0.5101
# Epoch 9/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0269 - accuracy: 0.5175 - val_loss: 0.0259 - val_accuracy: 0.5095
# Epoch 10/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0257 - accuracy: 0.5114 - val_loss: 0.0248 - val_accuracy: 0.5026
# Epoch 11/40
# 7/7 [==============================] - 2s 319ms/step - loss: 0.0248 - accuracy: 0.5074 - val_loss: 0.0241 - val_accuracy: 0.5030
# Epoch 12/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0240 - accuracy: 0.5081 - val_loss: 0.0233 - val_accuracy: 0.5051
# Epoch 13/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0232 - accuracy: 0.5152 - val_loss: 0.0225 - val_accuracy: 0.5252
# Epoch 14/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0222 - accuracy: 0.5605 - val_loss: 0.0212 - val_accuracy: 0.6183
# Epoch 15/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0207 - accuracy: 0.6801 - val_loss: 0.0193 - val_accuracy: 0.7529
# Epoch 16/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0185 - accuracy: 0.7907 - val_loss: 0.0166 - val_accuracy: 0.8488
# Epoch 17/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0157 - accuracy: 0.8893 - val_loss: 0.0139 - val_accuracy: 0.9380
# Epoch 18/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0130 - accuracy: 0.9580 - val_loss: 0.0113 - val_accuracy: 0.9667
# Epoch 19/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0105 - accuracy: 0.9707 - val_loss: 0.0090 - val_accuracy: 0.9747
# Epoch 20/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0083 - accuracy: 0.9764 - val_loss: 0.0071 - val_accuracy: 0.9765
# Epoch 21/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0065 - accuracy: 0.9768 - val_loss: 0.0054 - val_accuracy: 0.9753
# Epoch 22/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0049 - accuracy: 0.9772 - val_loss: 0.0040 - val_accuracy: 0.9782
# Epoch 23/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0035 - accuracy: 0.9785 - val_loss: 0.0028 - val_accuracy: 0.9779
# Epoch 24/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0025 - accuracy: 0.9794 - val_loss: 0.0021 - val_accuracy: 0.9798
# Epoch 25/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0019 - accuracy: 0.9804 - val_loss: 0.0017 - val_accuracy: 0.9808
# Epoch 26/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0016 - accuracy: 0.9818 - val_loss: 0.0014 - val_accuracy: 0.9822
# Epoch 27/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0013 - accuracy: 0.9830 - val_loss: 0.0012 - val_accuracy: 0.9834
# Epoch 28/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0012 - accuracy: 0.9841 - val_loss: 0.0011 - val_accuracy: 0.9840
# Epoch 29/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0011 - accuracy: 0.9847 - val_loss: 0.0010 - val_accuracy: 0.9848
# Epoch 30/40
# 7/7 [==============================] - 2s 272ms/step - loss: 9.7936e-04 - accuracy: 0.9852 - val_loss: 9.2278e-04 - val_accuracy: 0.9850
# Epoch 31/40
# 7/7 [==============================] - 2s 270ms/step - loss: 8.9939e-04 - accuracy: 0.9856 - val_loss: 8.5592e-04 - val_accuracy: 0.9856
# Epoch 32/40
# 7/7 [==============================] - 2s 278ms/step - loss: 8.3159e-04 - accuracy: 0.9862 - val_loss: 7.9389e-04 - val_accuracy: 0.9863
# Epoch 33/40
# 7/7 [==============================] - 2s 274ms/step - loss: 7.7430e-04 - accuracy: 0.9868 - val_loss: 7.4205e-04 - val_accuracy: 0.9868
# Epoch 34/40
# 7/7 [==============================] - 2s 279ms/step - loss: 7.2524e-04 - accuracy: 0.9872 - val_loss: 6.9764e-04 - val_accuracy: 0.9872
# Epoch 35/40
# 7/7 [==============================] - 2s 273ms/step - loss: 6.8268e-04 - accuracy: 0.9875 - val_loss: 6.5927e-04 - val_accuracy: 0.9876
# Epoch 36/40
# 7/7 [==============================] - 2s 278ms/step - loss: 6.4629e-04 - accuracy: 0.9880 - val_loss: 6.2124e-04 - val_accuracy: 0.9879
# Epoch 37/40
# 7/7 [==============================] - 2s 281ms/step - loss: 6.1281e-04 - accuracy: 0.9882 - val_loss: 5.9435e-04 - val_accuracy: 0.9881
# Epoch 38/40
# 7/7 [==============================] - 2s 285ms/step - loss: 6.0098e-04 - accuracy: 0.9882 - val_loss: 5.6674e-04 - val_accuracy: 0.9882
# Epoch 39/40
# 7/7 [==============================] - 2s 283ms/step - loss: 5.6526e-04 - accuracy: 0.9885 - val_loss: 5.4582e-04 - val_accuracy: 0.9884
# Epoch 40/40
# 7/7 [==============================] - 2s 275ms/step - loss: 5.3864e-04 - accuracy: 0.9887 - val_loss: 5.2395e-04 - val_accuracy: 0.9887

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v1/Left', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Left', options=load_locally)

# %%
load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Left', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([206, 60, 80, 32])

# %%
xm_train.shape[0]
# Out:
# 206

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[54  3]
#  [ 7 24]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92        57
#          1.0       0.89      0.77      0.83        31
#
#     accuracy                           0.89        88
#    macro avg       0.89      0.86      0.87        88
# weighted avg       0.89      0.89      0.88        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
