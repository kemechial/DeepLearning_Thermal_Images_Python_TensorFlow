# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.2-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.2
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Right45.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (203, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 40s 4s/step - loss: 0.1724 - accuracy: 0.3524 - val_loss: 0.0839 - val_accuracy: 0.3339
# Epoch 2/20
# 7/7 [==============================] - 3s 521ms/step - loss: 0.0490 - accuracy: 0.3960 - val_loss: 0.0310 - val_accuracy: 0.6493
# Epoch 3/20
# 7/7 [==============================] - 3s 527ms/step - loss: 0.0228 - accuracy: 0.7800 - val_loss: 0.0207 - val_accuracy: 0.9434
# Epoch 4/20
# 7/7 [==============================] - 3s 520ms/step - loss: 0.0154 - accuracy: 0.9585 - val_loss: 0.0109 - val_accuracy: 0.9468
# Epoch 5/20
# 7/7 [==============================] - 3s 515ms/step - loss: 0.0084 - accuracy: 0.9634 - val_loss: 0.0049 - val_accuracy: 0.9717
# Epoch 6/20
# 7/7 [==============================] - 4s 621ms/step - loss: 0.0035 - accuracy: 0.9754 - val_loss: 0.0029 - val_accuracy: 0.9690
# Epoch 7/20
# 7/7 [==============================] - 3s 516ms/step - loss: 0.0026 - accuracy: 0.9665 - val_loss: 0.0021 - val_accuracy: 0.9748
# Epoch 8/20
# 7/7 [==============================] - 3s 514ms/step - loss: 0.0019 - accuracy: 0.9733 - val_loss: 0.0017 - val_accuracy: 0.9746
# Epoch 9/20
# 7/7 [==============================] - 3s 524ms/step - loss: 0.0015 - accuracy: 0.9759 - val_loss: 0.0013 - val_accuracy: 0.9803
# Epoch 10/20
# 7/7 [==============================] - 3s 503ms/step - loss: 0.0013 - accuracy: 0.9817 - val_loss: 0.0012 - val_accuracy: 0.9828
# Epoch 11/20
# 7/7 [==============================] - 3s 497ms/step - loss: 0.0011 - accuracy: 0.9833 - val_loss: 0.0010 - val_accuracy: 0.9836
# Epoch 12/20
# 7/7 [==============================] - 3s 500ms/step - loss: 9.9324e-04 - accuracy: 0.9836 - val_loss: 9.5118e-04 - val_accuracy: 0.9838
# Epoch 13/20
# 7/7 [==============================] - 4s 537ms/step - loss: 9.0633e-04 - accuracy: 0.9834 - val_loss: 8.7278e-04 - val_accuracy: 0.9840
# Epoch 14/20
# 7/7 [==============================] - 3s 518ms/step - loss: 8.3765e-04 - accuracy: 0.9842 - val_loss: 8.2403e-04 - val_accuracy: 0.9846
# Epoch 15/20
# 7/7 [==============================] - 3s 507ms/step - loss: 7.8894e-04 - accuracy: 0.9849 - val_loss: 7.7136e-04 - val_accuracy: 0.9855
# Epoch 16/20
# 7/7 [==============================] - 3s 526ms/step - loss: 7.3932e-04 - accuracy: 0.9854 - val_loss: 7.2628e-04 - val_accuracy: 0.9856
# Epoch 17/20
# 7/7 [==============================] - 3s 522ms/step - loss: 6.9310e-04 - accuracy: 0.9858 - val_loss: 6.8514e-04 - val_accuracy: 0.9867
# Epoch 18/20
# 7/7 [==============================] - 3s 519ms/step - loss: 6.5264e-04 - accuracy: 0.9867 - val_loss: 6.4632e-04 - val_accuracy: 0.9869
# Epoch 19/20
# 7/7 [==============================] - 3s 524ms/step - loss: 6.1772e-04 - accuracy: 0.9871 - val_loss: 6.1306e-04 - val_accuracy: 0.9874
# Epoch 20/20
# 7/7 [==============================] - 5s 776ms/step - loss: 5.8578e-04 - accuracy: 0.9874 - val_loss: 5.7970e-04 - val_accuracy: 0.9876

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Yedek/Models_Static_v1/Right45', options=save_locally)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Yedek/Models_Static_v1/Right45', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([203, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 203

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[50  7]
#  [ 9 21]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.88      0.86        57
#          1.0       0.75      0.70      0.72        30
#
#     accuracy                           0.82        87
#    macro avg       0.80      0.79      0.79        87
# weighted avg       0.81      0.82      0.81        87

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
