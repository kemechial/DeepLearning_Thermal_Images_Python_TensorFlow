# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Requirement already satisfied: hickle in /usr/local/lib/python3.10/dist-packages (5.0.3)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.10.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Frontal.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (210, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
'''
cnn_autoencoder=CNN_Autoencoder()
dot_img_file = '/tmp/model_1.png'

keras.utils.plot_model(cnn_autoencoder.encoder,to_file=dot_img_file, show_shapes=False)
'''
# Out:
# "\ncnn_autoencoder=CNN_Autoencoder()\ndot_img_file = '/tmp/model_1.png'\n\nkeras.utils.plot_model(cnn_autoencoder.encoder,to_file=dot_img_file, show_shapes=False)\n"

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 7/7 [==============================] - 33s 3s/step - loss: 0.2284 - accuracy: 0.3081 - val_loss: 0.2152 - val_accuracy: 0.3657
# Epoch 2/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.1953 - accuracy: 0.3826 - val_loss: 0.1576 - val_accuracy: 0.4029
# Epoch 3/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.1378 - accuracy: 0.4020 - val_loss: 0.1245 - val_accuracy: 0.4032
# Epoch 4/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1045 - accuracy: 0.4365 - val_loss: 0.0848 - val_accuracy: 0.4733
# Epoch 5/40
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0755 - accuracy: 0.4885 - val_loss: 0.0652 - val_accuracy: 0.5142
# Epoch 6/40
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0604 - accuracy: 0.5256 - val_loss: 0.0546 - val_accuracy: 0.5661
# Epoch 7/40
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0518 - accuracy: 0.5789 - val_loss: 0.0479 - val_accuracy: 0.6022
# Epoch 8/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0456 - accuracy: 0.6117 - val_loss: 0.0427 - val_accuracy: 0.6162
# Epoch 9/40
# 7/7 [==============================] - 2s 312ms/step - loss: 0.0408 - accuracy: 0.6243 - val_loss: 0.0372 - val_accuracy: 0.6399
# Epoch 10/40
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0338 - accuracy: 0.6394 - val_loss: 0.0292 - val_accuracy: 0.6462
# Epoch 11/40
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0275 - accuracy: 0.6749 - val_loss: 0.0256 - val_accuracy: 0.6876
# Epoch 12/40
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0248 - accuracy: 0.6871 - val_loss: 0.0238 - val_accuracy: 0.6878
# Epoch 13/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0234 - accuracy: 0.6873 - val_loss: 0.0228 - val_accuracy: 0.6883
# Epoch 14/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0225 - accuracy: 0.6878 - val_loss: 0.0219 - val_accuracy: 0.6889
# Epoch 15/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0216 - accuracy: 0.6892 - val_loss: 0.0209 - val_accuracy: 0.6964
# Epoch 16/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0204 - accuracy: 0.7061 - val_loss: 0.0193 - val_accuracy: 0.7341
# Epoch 17/40
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0182 - accuracy: 0.7561 - val_loss: 0.0167 - val_accuracy: 0.7883
# Epoch 18/40
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0157 - accuracy: 0.7967 - val_loss: 0.0143 - val_accuracy: 0.8211
# Epoch 19/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0136 - accuracy: 0.8301 - val_loss: 0.0125 - val_accuracy: 0.8649
# Epoch 20/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0119 - accuracy: 0.8747 - val_loss: 0.0109 - val_accuracy: 0.8927
# Epoch 21/40
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0103 - accuracy: 0.8986 - val_loss: 0.0094 - val_accuracy: 0.9215
# Epoch 22/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0088 - accuracy: 0.9233 - val_loss: 0.0080 - val_accuracy: 0.9394
# Epoch 23/40
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0074 - accuracy: 0.9417 - val_loss: 0.0066 - val_accuracy: 0.9554
# Epoch 24/40
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0061 - accuracy: 0.9546 - val_loss: 0.0053 - val_accuracy: 0.9616
# Epoch 25/40
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0048 - accuracy: 0.9610 - val_loss: 0.0043 - val_accuracy: 0.9685
# Epoch 26/40
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0039 - accuracy: 0.9662 - val_loss: 0.0035 - val_accuracy: 0.9719
# Epoch 27/40
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0032 - accuracy: 0.9700 - val_loss: 0.0029 - val_accuracy: 0.9723
# Epoch 28/40
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0027 - accuracy: 0.9718 - val_loss: 0.0024 - val_accuracy: 0.9750
# Epoch 29/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0023 - accuracy: 0.9742 - val_loss: 0.0021 - val_accuracy: 0.9772
# Epoch 30/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0020 - accuracy: 0.9761 - val_loss: 0.0019 - val_accuracy: 0.9779
# Epoch 31/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0018 - accuracy: 0.9770 - val_loss: 0.0017 - val_accuracy: 0.9794
# Epoch 32/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0016 - accuracy: 0.9783 - val_loss: 0.0015 - val_accuracy: 0.9806
# Epoch 33/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0015 - accuracy: 0.9794 - val_loss: 0.0014 - val_accuracy: 0.9809
# Epoch 34/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0013 - accuracy: 0.9802 - val_loss: 0.0013 - val_accuracy: 0.9816
# Epoch 35/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0012 - accuracy: 0.9805 - val_loss: 0.0012 - val_accuracy: 0.9818
# Epoch 36/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0011 - accuracy: 0.9808 - val_loss: 0.0011 - val_accuracy: 0.9818
# Epoch 37/40
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0010 - accuracy: 0.9810 - val_loss: 0.0010 - val_accuracy: 0.9824
# Epoch 38/40
# 7/7 [==============================] - 2s 276ms/step - loss: 9.6460e-04 - accuracy: 0.9815 - val_loss: 9.4520e-04 - val_accuracy: 0.9828
# Epoch 39/40
# 7/7 [==============================] - 2s 265ms/step - loss: 9.1526e-04 - accuracy: 0.9816 - val_loss: 8.8951e-04 - val_accuracy: 0.9831
# Epoch 40/40
# 7/7 [==============================] - 2s 264ms/step - loss: 8.7101e-04 - accuracy: 0.9820 - val_loss: 8.4967e-04 - val_accuracy: 0.9831

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v1/Frontal', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Frontal', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([210, 60, 80, 32])

# %%
xm_train.shape[0]
# Out:
# 210

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[53  4]
#  [ 4 29]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93        57
#          1.0       0.88      0.88      0.88        33
#
#     accuracy                           0.91        90
#    macro avg       0.90      0.90      0.90        90
# weighted avg       0.91      0.91      0.91        90

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
