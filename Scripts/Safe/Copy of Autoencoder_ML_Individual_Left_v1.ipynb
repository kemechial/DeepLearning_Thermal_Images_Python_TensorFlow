# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.2-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.2
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Left.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (206, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 35s 4s/step - loss: 0.1381 - accuracy: 0.4849 - val_loss: 0.1168 - val_accuracy: 0.4987
# Epoch 2/20
# 7/7 [==============================] - 3s 521ms/step - loss: 0.1042 - accuracy: 0.5034 - val_loss: 0.0962 - val_accuracy: 0.4984
# Epoch 3/20
# 7/7 [==============================] - 4s 547ms/step - loss: 0.0827 - accuracy: 0.5026 - val_loss: 0.0770 - val_accuracy: 0.4964
# Epoch 4/20
# 7/7 [==============================] - 3s 524ms/step - loss: 0.0743 - accuracy: 0.5005 - val_loss: 0.0735 - val_accuracy: 0.4963
# Epoch 5/20
# 7/7 [==============================] - 3s 521ms/step - loss: 0.0707 - accuracy: 0.5013 - val_loss: 0.0699 - val_accuracy: 0.4966
# Epoch 6/20
# 7/7 [==============================] - 4s 656ms/step - loss: 0.0681 - accuracy: 0.5010 - val_loss: 0.0680 - val_accuracy: 0.4961
# Epoch 7/20
# 7/7 [==============================] - 4s 534ms/step - loss: 0.0662 - accuracy: 0.5011 - val_loss: 0.0657 - val_accuracy: 0.4968
# Epoch 8/20
# 7/7 [==============================] - 3s 520ms/step - loss: 0.0645 - accuracy: 0.5016 - val_loss: 0.0646 - val_accuracy: 0.4973
# Epoch 9/20
# 7/7 [==============================] - 4s 533ms/step - loss: 0.0639 - accuracy: 0.5011 - val_loss: 0.0644 - val_accuracy: 0.4956
# Epoch 10/20
# 7/7 [==============================] - 3s 526ms/step - loss: 0.0636 - accuracy: 0.5011 - val_loss: 0.0640 - val_accuracy: 0.4978
# Epoch 11/20
# 7/7 [==============================] - 3s 511ms/step - loss: 0.0633 - accuracy: 0.5030 - val_loss: 0.0638 - val_accuracy: 0.4986
# Epoch 12/20
# 7/7 [==============================] - 3s 513ms/step - loss: 0.0607 - accuracy: 0.5037 - val_loss: 0.0382 - val_accuracy: 0.5012
# Epoch 13/20
# 7/7 [==============================] - 4s 563ms/step - loss: 0.0205 - accuracy: 0.6818 - val_loss: 0.0167 - val_accuracy: 0.9777
# Epoch 14/20
# 7/7 [==============================] - 4s 539ms/step - loss: 0.0130 - accuracy: 0.9833 - val_loss: 0.0072 - val_accuracy: 0.9776
# Epoch 15/20
# 7/7 [==============================] - 4s 531ms/step - loss: 0.0070 - accuracy: 0.9729 - val_loss: 0.0055 - val_accuracy: 0.9776
# Epoch 16/20
# 7/7 [==============================] - 4s 548ms/step - loss: 0.0037 - accuracy: 0.9810 - val_loss: 0.0024 - val_accuracy: 0.9695
# Epoch 17/20
# 7/7 [==============================] - 3s 514ms/step - loss: 0.0021 - accuracy: 0.9757 - val_loss: 0.0017 - val_accuracy: 0.9634
# Epoch 18/20
# 7/7 [==============================] - 3s 519ms/step - loss: 0.0014 - accuracy: 0.9708 - val_loss: 0.0011 - val_accuracy: 0.9721
# Epoch 19/20
# 7/7 [==============================] - 4s 534ms/step - loss: 0.0011 - accuracy: 0.9797 - val_loss: 9.8231e-04 - val_accuracy: 0.9886
# Epoch 20/20
# 7/7 [==============================] - 4s 557ms/step - loss: 9.1214e-04 - accuracy: 0.9855 - val_loss: 8.6490e-04 - val_accuracy: 0.9870

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v1/Left', options=save_locally)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Left', options=load_locally)

# %%
load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Left', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([206, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 206

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[53  4]
#  [ 7 24]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.91        57
#          1.0       0.86      0.77      0.81        31
#
#     accuracy                           0.88        88
#    macro avg       0.87      0.85      0.86        88
# weighted avg       0.87      0.88      0.87        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
