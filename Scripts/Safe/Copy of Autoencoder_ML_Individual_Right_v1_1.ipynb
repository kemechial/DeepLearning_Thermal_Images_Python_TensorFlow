# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# WARNING:tensorflow:TPU system grpc://10.26.219.90:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:6 out of the last 6 calls to <function initialize_tpu_system.<locals>._tpu_init_fn at 0x7c69fe6628c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Requirement already satisfied: hickle in /usr/local/lib/python3.10/dist-packages (5.0.2)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Right.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (208, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=False,validation_data=(X_test,X_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 41s 4s/step - loss: 0.0760 - accuracy: 0.5807 - val_loss: 0.0242 - val_accuracy: 0.9588
# Epoch 2/20
# 7/7 [==============================] - 4s 545ms/step - loss: 0.0191 - accuracy: 0.8727 - val_loss: 0.0176 - val_accuracy: 0.8196
# Epoch 3/20
# 7/7 [==============================] - 3s 500ms/step - loss: 0.0134 - accuracy: 0.8697 - val_loss: 0.0095 - val_accuracy: 0.9490
# Epoch 4/20
# 7/7 [==============================] - 3s 498ms/step - loss: 0.0082 - accuracy: 0.9406 - val_loss: 0.0061 - val_accuracy: 0.9744
# Epoch 5/20
# 7/7 [==============================] - 3s 495ms/step - loss: 0.0051 - accuracy: 0.9804 - val_loss: 0.0033 - val_accuracy: 0.9819
# Epoch 6/20
# 7/7 [==============================] - 3s 527ms/step - loss: 0.0028 - accuracy: 0.9795 - val_loss: 0.0019 - val_accuracy: 0.9837
# Epoch 7/20
# 7/7 [==============================] - 3s 504ms/step - loss: 0.0018 - accuracy: 0.9828 - val_loss: 0.0018 - val_accuracy: 0.9831
# Epoch 8/20
# 7/7 [==============================] - 3s 500ms/step - loss: 0.0017 - accuracy: 0.9818 - val_loss: 0.0015 - val_accuracy: 0.9859
# Epoch 9/20
# 7/7 [==============================] - 3s 505ms/step - loss: 0.0014 - accuracy: 0.9834 - val_loss: 0.0013 - val_accuracy: 0.9743
# Epoch 10/20
# 7/7 [==============================] - 3s 504ms/step - loss: 0.0013 - accuracy: 0.9802 - val_loss: 0.0012 - val_accuracy: 0.9844
# Epoch 11/20
# 7/7 [==============================] - 3s 499ms/step - loss: 0.0011 - accuracy: 0.9838 - val_loss: 0.0010 - val_accuracy: 0.9850
# Epoch 12/20
# 7/7 [==============================] - 3s 499ms/step - loss: 0.0010 - accuracy: 0.9848 - val_loss: 9.3415e-04 - val_accuracy: 0.9840
# Epoch 13/20
# 7/7 [==============================] - 5s 719ms/step - loss: 9.1917e-04 - accuracy: 0.9834 - val_loss: 8.3271e-04 - val_accuracy: 0.9832
# Epoch 14/20
# 7/7 [==============================] - 4s 602ms/step - loss: 8.2506e-04 - accuracy: 0.9835 - val_loss: 7.4784e-04 - val_accuracy: 0.9855
# Epoch 15/20
# 7/7 [==============================] - 3s 497ms/step - loss: 7.4490e-04 - accuracy: 0.9851 - val_loss: 6.8544e-04 - val_accuracy: 0.9853
# Epoch 16/20
# 7/7 [==============================] - 3s 504ms/step - loss: 6.8580e-04 - accuracy: 0.9856 - val_loss: 6.3262e-04 - val_accuracy: 0.9852
# Epoch 17/20
# 7/7 [==============================] - 3s 503ms/step - loss: 6.3692e-04 - accuracy: 0.9858 - val_loss: 5.9357e-04 - val_accuracy: 0.9850
# Epoch 18/20
# 7/7 [==============================] - 3s 500ms/step - loss: 5.9786e-04 - accuracy: 0.9853 - val_loss: 5.5863e-04 - val_accuracy: 0.9859
# Epoch 19/20
# 7/7 [==============================] - 3s 502ms/step - loss: 5.6391e-04 - accuracy: 0.9861 - val_loss: 5.2718e-04 - val_accuracy: 0.9873
# Epoch 20/20
# 7/7 [==============================] - 4s 543ms/step - loss: 5.3331e-04 - accuracy: 0.9866 - val_loss: 5.0159e-04 - val_accuracy: 0.9878

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v1/Right1', options=save_locally)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Right1', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([208, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 208

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[52  5]
#  [ 9 22]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88        57
#          1.0       0.81      0.71      0.76        31
#
#     accuracy                           0.84        88
#    macro avg       0.83      0.81      0.82        88
# weighted avg       0.84      0.84      0.84        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
