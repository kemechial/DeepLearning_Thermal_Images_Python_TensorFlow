# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Requirement already satisfied: hickle in /usr/local/lib/python3.10/dist-packages (5.0.2)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Left45.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (205, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 45s 4s/step - loss: 0.1845 - accuracy: 0.4373 - val_loss: 0.0754 - val_accuracy: 0.6369
# Epoch 2/20
# 7/7 [==============================] - 3s 519ms/step - loss: 0.0538 - accuracy: 0.6436 - val_loss: 0.0272 - val_accuracy: 0.6374
# Epoch 3/20
# 7/7 [==============================] - 3s 514ms/step - loss: 0.0273 - accuracy: 0.6456 - val_loss: 0.0259 - val_accuracy: 0.8188
# Epoch 4/20
# 7/7 [==============================] - 3s 513ms/step - loss: 0.0216 - accuracy: 0.9148 - val_loss: 0.0175 - val_accuracy: 0.9744
# Epoch 5/20
# 7/7 [==============================] - 3s 509ms/step - loss: 0.0141 - accuracy: 0.9595 - val_loss: 0.0123 - val_accuracy: 0.9422
# Epoch 6/20
# 7/7 [==============================] - 4s 613ms/step - loss: 0.0109 - accuracy: 0.9694 - val_loss: 0.0096 - val_accuracy: 0.9848
# Epoch 7/20
# 7/7 [==============================] - 3s 508ms/step - loss: 0.0082 - accuracy: 0.9703 - val_loss: 0.0063 - val_accuracy: 0.9628
# Epoch 8/20
# 7/7 [==============================] - 3s 518ms/step - loss: 0.0052 - accuracy: 0.9756 - val_loss: 0.0038 - val_accuracy: 0.9587
# Epoch 9/20
# 7/7 [==============================] - 3s 515ms/step - loss: 0.0030 - accuracy: 0.9719 - val_loss: 0.0025 - val_accuracy: 0.9858
# Epoch 10/20
# 7/7 [==============================] - 3s 499ms/step - loss: 0.0022 - accuracy: 0.9859 - val_loss: 0.0020 - val_accuracy: 0.9836
# Epoch 11/20
# 7/7 [==============================] - 3s 492ms/step - loss: 0.0017 - accuracy: 0.9850 - val_loss: 0.0016 - val_accuracy: 0.9846
# Epoch 12/20
# 7/7 [==============================] - 3s 492ms/step - loss: 0.0015 - accuracy: 0.9823 - val_loss: 0.0015 - val_accuracy: 0.9778
# Epoch 13/20
# 7/7 [==============================] - 3s 519ms/step - loss: 0.0014 - accuracy: 0.9798 - val_loss: 0.0013 - val_accuracy: 0.9811
# Epoch 14/20
# 7/7 [==============================] - 3s 515ms/step - loss: 0.0012 - accuracy: 0.9843 - val_loss: 0.0012 - val_accuracy: 0.9852
# Epoch 15/20
# 7/7 [==============================] - 3s 514ms/step - loss: 0.0011 - accuracy: 0.9853 - val_loss: 0.0011 - val_accuracy: 0.9823
# Epoch 16/20
# 7/7 [==============================] - 3s 505ms/step - loss: 0.0010 - accuracy: 0.9846 - val_loss: 0.0010 - val_accuracy: 0.9850
# Epoch 17/20
# 7/7 [==============================] - 4s 538ms/step - loss: 9.7672e-04 - accuracy: 0.9856 - val_loss: 9.5287e-04 - val_accuracy: 0.9848
# Epoch 18/20
# 7/7 [==============================] - 3s 506ms/step - loss: 9.0935e-04 - accuracy: 0.9860 - val_loss: 8.8855e-04 - val_accuracy: 0.9855
# Epoch 19/20
# 7/7 [==============================] - 3s 504ms/step - loss: 8.5436e-04 - accuracy: 0.9859 - val_loss: 8.5478e-04 - val_accuracy: 0.9862
# Epoch 20/20
# 7/7 [==============================] - 3s 516ms/step - loss: 8.0829e-04 - accuracy: 0.9862 - val_loss: 7.9671e-04 - val_accuracy: 0.9866

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Yedek/Models_Static_v1/Left45', options=save_locally)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Yedek/Models_Static_v1/Left45', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([205, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 205

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[50  7]
#  [ 6 24]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.88      0.88        57
#          1.0       0.77      0.80      0.79        30
#
#     accuracy                           0.85        87
#    macro avg       0.83      0.84      0.84        87
# weighted avg       0.85      0.85      0.85        87

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
