# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# WARNING:tensorflow:TPU system grpc://10.19.231.234:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Requirement already satisfied: hickle in /usr/local/lib/python3.10/dist-packages (5.0.2)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.9.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.23.5)
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Right.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (208, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.MaxPooling2D(2, strides=2),
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2D(32, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(16, 3, strides=1, padding='same', activation='relu'),
            layers.UpSampling2D(2),
            layers.Conv2D(3, 3, strides=1, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=20

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 13/13 [==============================] - 30s 2s/step - loss: 0.1021 - accuracy: 0.2696 - val_loss: 0.0831 - val_accuracy: 0.4902
# Epoch 2/40
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0634 - accuracy: 0.4995 - val_loss: 0.0285 - val_accuracy: 0.4949
# Epoch 3/40
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0264 - accuracy: 0.6868 - val_loss: 0.0229 - val_accuracy: 0.5059
# Epoch 4/40
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0197 - accuracy: 0.6581 - val_loss: 0.0131 - val_accuracy: 0.9599
# Epoch 5/40
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0078 - accuracy: 0.9335 - val_loss: 0.0028 - val_accuracy: 0.9695
# Epoch 6/40
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0020 - accuracy: 0.9709 - val_loss: 0.0016 - val_accuracy: 0.9699
# Epoch 7/40
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0012 - accuracy: 0.9760 - val_loss: 9.6543e-04 - val_accuracy: 0.9840
# Epoch 8/40
# 13/13 [==============================] - 3s 210ms/step - loss: 8.8863e-04 - accuracy: 0.9838 - val_loss: 7.4893e-04 - val_accuracy: 0.9835
# Epoch 9/40
# 13/13 [==============================] - 3s 208ms/step - loss: 7.0129e-04 - accuracy: 0.9872 - val_loss: 6.0457e-04 - val_accuracy: 0.9882
# Epoch 10/40
# 13/13 [==============================] - 3s 203ms/step - loss: 5.8650e-04 - accuracy: 0.9882 - val_loss: 5.1502e-04 - val_accuracy: 0.9894
# Epoch 11/40
# 13/13 [==============================] - 3s 206ms/step - loss: 5.0913e-04 - accuracy: 0.9893 - val_loss: 4.7078e-04 - val_accuracy: 0.9901
# Epoch 12/40
# 13/13 [==============================] - 3s 222ms/step - loss: 4.7400e-04 - accuracy: 0.9895 - val_loss: 4.1984e-04 - val_accuracy: 0.9906
# Epoch 13/40
# 13/13 [==============================] - 3s 207ms/step - loss: 4.3185e-04 - accuracy: 0.9900 - val_loss: 4.0052e-04 - val_accuracy: 0.9901
# Epoch 14/40
# 13/13 [==============================] - 3s 206ms/step - loss: 3.8635e-04 - accuracy: 0.9906 - val_loss: 3.5402e-04 - val_accuracy: 0.9917
# Epoch 15/40
# 13/13 [==============================] - 3s 208ms/step - loss: 3.4749e-04 - accuracy: 0.9905 - val_loss: 3.1832e-04 - val_accuracy: 0.9917
# Epoch 16/40
# 13/13 [==============================] - 3s 269ms/step - loss: 3.1617e-04 - accuracy: 0.9909 - val_loss: 3.0015e-04 - val_accuracy: 0.9885
# Epoch 17/40
# 13/13 [==============================] - 3s 213ms/step - loss: 2.9939e-04 - accuracy: 0.9906 - val_loss: 2.7025e-04 - val_accuracy: 0.9921
# Epoch 18/40
# 13/13 [==============================] - 3s 204ms/step - loss: 2.7711e-04 - accuracy: 0.9913 - val_loss: 2.4936e-04 - val_accuracy: 0.9923
# Epoch 19/40
# 13/13 [==============================] - 3s 213ms/step - loss: 2.5881e-04 - accuracy: 0.9912 - val_loss: 2.4684e-04 - val_accuracy: 0.9917
# Epoch 20/40
# 13/13 [==============================] - 3s 212ms/step - loss: 2.7117e-04 - accuracy: 0.9911 - val_loss: 2.4324e-04 - val_accuracy: 0.9918
# Epoch 21/40
# 13/13 [==============================] - 3s 217ms/step - loss: 2.6153e-04 - accuracy: 0.9910 - val_loss: 2.3220e-04 - val_accuracy: 0.9902
# Epoch 22/40
# 13/13 [==============================] - 3s 212ms/step - loss: 2.5394e-04 - accuracy: 0.9911 - val_loss: 2.2170e-04 - val_accuracy: 0.9907
# Epoch 23/40
# 13/13 [==============================] - 3s 206ms/step - loss: 2.2248e-04 - accuracy: 0.9915 - val_loss: 2.0375e-04 - val_accuracy: 0.9928
# Epoch 24/40
# 13/13 [==============================] - 3s 206ms/step - loss: 2.0998e-04 - accuracy: 0.9920 - val_loss: 1.9652e-04 - val_accuracy: 0.9928
# Epoch 25/40
# 13/13 [==============================] - 3s 205ms/step - loss: 2.0250e-04 - accuracy: 0.9921 - val_loss: 1.9176e-04 - val_accuracy: 0.9928
# Epoch 26/40
# 13/13 [==============================] - 3s 213ms/step - loss: 1.9836e-04 - accuracy: 0.9921 - val_loss: 1.9032e-04 - val_accuracy: 0.9931
# Epoch 27/40
# 13/13 [==============================] - 3s 205ms/step - loss: 2.0135e-04 - accuracy: 0.9922 - val_loss: 2.1916e-04 - val_accuracy: 0.9906
# Epoch 28/40
# 13/13 [==============================] - 3s 208ms/step - loss: 1.9843e-04 - accuracy: 0.9922 - val_loss: 2.0668e-04 - val_accuracy: 0.9918
# Epoch 29/40
# 13/13 [==============================] - 3s 205ms/step - loss: 1.9468e-04 - accuracy: 0.9923 - val_loss: 1.7462e-04 - val_accuracy: 0.9929
# Epoch 30/40
# 13/13 [==============================] - 3s 226ms/step - loss: 2.1787e-04 - accuracy: 0.9918 - val_loss: 2.0402e-04 - val_accuracy: 0.9919
# Epoch 31/40
# 13/13 [==============================] - 3s 208ms/step - loss: 2.2132e-04 - accuracy: 0.9915 - val_loss: 2.4078e-04 - val_accuracy: 0.9929
# Epoch 32/40
# 13/13 [==============================] - 3s 210ms/step - loss: 2.0094e-04 - accuracy: 0.9919 - val_loss: 1.6673e-04 - val_accuracy: 0.9934
# Epoch 33/40
# 13/13 [==============================] - 3s 273ms/step - loss: 1.7378e-04 - accuracy: 0.9924 - val_loss: 1.6688e-04 - val_accuracy: 0.9932
# Epoch 34/40
# 13/13 [==============================] - 3s 218ms/step - loss: 1.6872e-04 - accuracy: 0.9925 - val_loss: 1.6466e-04 - val_accuracy: 0.9924
# Epoch 35/40
# 13/13 [==============================] - 3s 224ms/step - loss: 1.6642e-04 - accuracy: 0.9925 - val_loss: 1.8141e-04 - val_accuracy: 0.9921
# Epoch 36/40
# 13/13 [==============================] - 3s 207ms/step - loss: 1.8364e-04 - accuracy: 0.9921 - val_loss: 1.5444e-04 - val_accuracy: 0.9930
# Epoch 37/40
# 13/13 [==============================] - 3s 212ms/step - loss: 1.7694e-04 - accuracy: 0.9923 - val_loss: 1.5892e-04 - val_accuracy: 0.9936
# Epoch 38/40
# 13/13 [==============================] - 3s 205ms/step - loss: 1.7855e-04 - accuracy: 0.9925 - val_loss: 1.9302e-04 - val_accuracy: 0.9929
# Epoch 39/40
# 13/13 [==============================] - 3s 221ms/step - loss: 1.6578e-04 - accuracy: 0.9928 - val_loss: 1.4617e-04 - val_accuracy: 0.9934
# Epoch 40/40
# 13/13 [==============================] - 3s 204ms/step - loss: 1.5464e-04 - accuracy: 0.9927 - val_loss: 1.5098e-04 - val_accuracy: 0.9935

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v1/Right', options=save_locally)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v1/Right', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([208, 120, 160, 32])

# %%
xm_train.shape[0]
# Out:
# 208

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[52  5]
#  [ 9 22]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88        57
#          1.0       0.81      0.71      0.76        31
#
#     accuracy                           0.84        88
#    macro avg       0.83      0.81      0.82        88
# weighted avg       0.84      0.84      0.84        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
