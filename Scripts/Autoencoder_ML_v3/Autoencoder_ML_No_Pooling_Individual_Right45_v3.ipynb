# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.10.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Right45.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (203, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 7/7 [==============================] - 58s 7s/step - loss: 0.2166 - accuracy: 0.3263 - val_loss: 0.1905 - val_accuracy: 0.3607
# Epoch 2/40
# 7/7 [==============================] - 2s 290ms/step - loss: 0.1584 - accuracy: 0.3829 - val_loss: 0.1250 - val_accuracy: 0.4123
# Epoch 3/40
# 7/7 [==============================] - 2s 284ms/step - loss: 0.1162 - accuracy: 0.4377 - val_loss: 0.0912 - val_accuracy: 0.4656
# Epoch 4/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0824 - accuracy: 0.4781 - val_loss: 0.0632 - val_accuracy: 0.5018
# Epoch 5/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0546 - accuracy: 0.5076 - val_loss: 0.0423 - val_accuracy: 0.5326
# Epoch 6/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0384 - accuracy: 0.5756 - val_loss: 0.0331 - val_accuracy: 0.6452
# Epoch 7/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0312 - accuracy: 0.6439 - val_loss: 0.0283 - val_accuracy: 0.6474
# Epoch 8/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0277 - accuracy: 0.6424 - val_loss: 0.0265 - val_accuracy: 0.6471
# Epoch 9/40
# 7/7 [==============================] - 2s 313ms/step - loss: 0.0262 - accuracy: 0.6424 - val_loss: 0.0252 - val_accuracy: 0.6472
# Epoch 10/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0251 - accuracy: 0.6427 - val_loss: 0.0242 - val_accuracy: 0.6478
# Epoch 11/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0242 - accuracy: 0.6432 - val_loss: 0.0234 - val_accuracy: 0.6489
# Epoch 12/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0233 - accuracy: 0.6490 - val_loss: 0.0225 - val_accuracy: 0.6620
# Epoch 13/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0223 - accuracy: 0.6667 - val_loss: 0.0213 - val_accuracy: 0.6871
# Epoch 14/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0210 - accuracy: 0.7055 - val_loss: 0.0198 - val_accuracy: 0.7571
# Epoch 15/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0193 - accuracy: 0.7721 - val_loss: 0.0181 - val_accuracy: 0.8137
# Epoch 16/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0176 - accuracy: 0.8333 - val_loss: 0.0164 - val_accuracy: 0.8667
# Epoch 17/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0158 - accuracy: 0.8775 - val_loss: 0.0145 - val_accuracy: 0.8890
# Epoch 18/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0140 - accuracy: 0.8894 - val_loss: 0.0127 - val_accuracy: 0.8918
# Epoch 19/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0122 - accuracy: 0.8915 - val_loss: 0.0110 - val_accuracy: 0.8929
# Epoch 20/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0105 - accuracy: 0.8917 - val_loss: 0.0095 - val_accuracy: 0.8925
# Epoch 21/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0091 - accuracy: 0.8914 - val_loss: 0.0081 - val_accuracy: 0.8945
# Epoch 22/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0077 - accuracy: 0.8959 - val_loss: 0.0069 - val_accuracy: 0.9155
# Epoch 23/40
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0065 - accuracy: 0.9249 - val_loss: 0.0058 - val_accuracy: 0.9414
# Epoch 24/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0055 - accuracy: 0.9439 - val_loss: 0.0050 - val_accuracy: 0.9501
# Epoch 25/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0048 - accuracy: 0.9551 - val_loss: 0.0043 - val_accuracy: 0.9625
# Epoch 26/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0041 - accuracy: 0.9674 - val_loss: 0.0037 - val_accuracy: 0.9719
# Epoch 27/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0036 - accuracy: 0.9739 - val_loss: 0.0033 - val_accuracy: 0.9745
# Epoch 28/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0031 - accuracy: 0.9756 - val_loss: 0.0029 - val_accuracy: 0.9758
# Epoch 29/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0028 - accuracy: 0.9767 - val_loss: 0.0026 - val_accuracy: 0.9768
# Epoch 30/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0025 - accuracy: 0.9776 - val_loss: 0.0023 - val_accuracy: 0.9775
# Epoch 31/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0022 - accuracy: 0.9783 - val_loss: 0.0020 - val_accuracy: 0.9783
# Epoch 32/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0020 - accuracy: 0.9789 - val_loss: 0.0018 - val_accuracy: 0.9791
# Epoch 33/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0018 - accuracy: 0.9795 - val_loss: 0.0016 - val_accuracy: 0.9793
# Epoch 34/40
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0016 - accuracy: 0.9800 - val_loss: 0.0015 - val_accuracy: 0.9798
# Epoch 35/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0014 - accuracy: 0.9805 - val_loss: 0.0014 - val_accuracy: 0.9803
# Epoch 36/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0013 - accuracy: 0.9809 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 37/40
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0012 - accuracy: 0.9814 - val_loss: 0.0011 - val_accuracy: 0.9811
# Epoch 38/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0011 - accuracy: 0.9817 - val_loss: 0.0011 - val_accuracy: 0.9817
# Epoch 39/40
# 7/7 [==============================] - 2s 347ms/step - loss: 0.0010 - accuracy: 0.9822 - val_loss: 9.9303e-04 - val_accuracy: 0.9822
# Epoch 40/40
# 7/7 [==============================] - 2s 276ms/step - loss: 9.5821e-04 - accuracy: 0.9827 - val_loss: 9.2479e-04 - val_accuracy: 0.9826

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Yedek/Models_Static_v3/Right45', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Yedek/Models_Static_v3/Right45', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([203, 60, 80, 32])

# %%
xm_train.shape[0]
# Out:
# 203

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[50  7]
#  [ 7 23]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88        57
#          1.0       0.77      0.77      0.77        30
#
#     accuracy                           0.84        87
#    macro avg       0.82      0.82      0.82        87
# weighted avg       0.84      0.84      0.84        87

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
