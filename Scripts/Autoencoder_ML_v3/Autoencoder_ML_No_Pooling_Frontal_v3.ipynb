# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Requirement already satisfied: hickle in /usr/local/lib/python3.10/dist-packages (5.0.3)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.10.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Frontal.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (210, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
'''
cnn_autoencoder=CNN_Autoencoder()
dot_img_file = '/tmp/model_1.png'

keras.utils.plot_model(cnn_autoencoder.encoder,to_file=dot_img_file, show_shapes=False)
'''
# Out:
# "\ncnn_autoencoder=CNN_Autoencoder()\ndot_img_file = '/tmp/model_1.png'\n\nkeras.utils.plot_model(cnn_autoencoder.encoder,to_file=dot_img_file, show_shapes=False)\n"

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 7/7 [==============================] - 31s 3s/step - loss: 0.2225 - accuracy: 0.3776 - val_loss: 0.1971 - val_accuracy: 0.3986
# Epoch 2/40
# 7/7 [==============================] - 2s 266ms/step - loss: 0.1617 - accuracy: 0.4008 - val_loss: 0.1309 - val_accuracy: 0.4105
# Epoch 3/40
# 7/7 [==============================] - 2s 265ms/step - loss: 0.1192 - accuracy: 0.4096 - val_loss: 0.0974 - val_accuracy: 0.4414
# Epoch 4/40
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0892 - accuracy: 0.4447 - val_loss: 0.0761 - val_accuracy: 0.4763
# Epoch 5/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0692 - accuracy: 0.4918 - val_loss: 0.0590 - val_accuracy: 0.5176
# Epoch 6/40
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0527 - accuracy: 0.5441 - val_loss: 0.0454 - val_accuracy: 0.5965
# Epoch 7/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0419 - accuracy: 0.6321 - val_loss: 0.0383 - val_accuracy: 0.6570
# Epoch 8/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0362 - accuracy: 0.6685 - val_loss: 0.0344 - val_accuracy: 0.6812
# Epoch 9/40
# 7/7 [==============================] - 2s 317ms/step - loss: 0.0330 - accuracy: 0.6832 - val_loss: 0.0317 - val_accuracy: 0.6890
# Epoch 10/40
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0299 - accuracy: 0.6955 - val_loss: 0.0265 - val_accuracy: 0.7465
# Epoch 11/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0232 - accuracy: 0.7755 - val_loss: 0.0203 - val_accuracy: 0.7952
# Epoch 12/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0194 - accuracy: 0.7932 - val_loss: 0.0176 - val_accuracy: 0.8382
# Epoch 13/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0169 - accuracy: 0.8852 - val_loss: 0.0156 - val_accuracy: 0.9294
# Epoch 14/40
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0149 - accuracy: 0.9408 - val_loss: 0.0138 - val_accuracy: 0.9575
# Epoch 15/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0133 - accuracy: 0.9622 - val_loss: 0.0123 - val_accuracy: 0.9727
# Epoch 16/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0119 - accuracy: 0.9713 - val_loss: 0.0110 - val_accuracy: 0.9732
# Epoch 17/40
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0106 - accuracy: 0.9703 - val_loss: 0.0098 - val_accuracy: 0.9713
# Epoch 18/40
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0094 - accuracy: 0.9686 - val_loss: 0.0086 - val_accuracy: 0.9688
# Epoch 19/40
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0081 - accuracy: 0.9652 - val_loss: 0.0073 - val_accuracy: 0.9691
# Epoch 20/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0068 - accuracy: 0.9651 - val_loss: 0.0060 - val_accuracy: 0.9669
# Epoch 21/40
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0056 - accuracy: 0.9659 - val_loss: 0.0049 - val_accuracy: 0.9699
# Epoch 22/40
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0045 - accuracy: 0.9686 - val_loss: 0.0040 - val_accuracy: 0.9731
# Epoch 23/40
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0037 - accuracy: 0.9709 - val_loss: 0.0033 - val_accuracy: 0.9743
# Epoch 24/40
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0031 - accuracy: 0.9723 - val_loss: 0.0028 - val_accuracy: 0.9746
# Epoch 25/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0026 - accuracy: 0.9741 - val_loss: 0.0023 - val_accuracy: 0.9772
# Epoch 26/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0022 - accuracy: 0.9760 - val_loss: 0.0020 - val_accuracy: 0.9777
# Epoch 27/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0019 - accuracy: 0.9771 - val_loss: 0.0017 - val_accuracy: 0.9800
# Epoch 28/40
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0016 - accuracy: 0.9786 - val_loss: 0.0015 - val_accuracy: 0.9808
# Epoch 29/40
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0015 - accuracy: 0.9792 - val_loss: 0.0014 - val_accuracy: 0.9809
# Epoch 30/40
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0013 - accuracy: 0.9803 - val_loss: 0.0012 - val_accuracy: 0.9824
# Epoch 31/40
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0012 - accuracy: 0.9812 - val_loss: 0.0012 - val_accuracy: 0.9827
# Epoch 32/40
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0011 - accuracy: 0.9817 - val_loss: 0.0011 - val_accuracy: 0.9830
# Epoch 33/40
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0010 - accuracy: 0.9822 - val_loss: 0.0010 - val_accuracy: 0.9835
# Epoch 34/40
# 7/7 [==============================] - 2s 272ms/step - loss: 9.7926e-04 - accuracy: 0.9823 - val_loss: 9.5220e-04 - val_accuracy: 0.9834
# Epoch 35/40
# 7/7 [==============================] - 2s 267ms/step - loss: 9.3137e-04 - accuracy: 0.9825 - val_loss: 9.1279e-04 - val_accuracy: 0.9841
# Epoch 36/40
# 7/7 [==============================] - 2s 269ms/step - loss: 8.8282e-04 - accuracy: 0.9832 - val_loss: 8.7359e-04 - val_accuracy: 0.9841
# Epoch 37/40
# 7/7 [==============================] - 2s 264ms/step - loss: 8.4760e-04 - accuracy: 0.9834 - val_loss: 8.4411e-04 - val_accuracy: 0.9835
# Epoch 38/40
# 7/7 [==============================] - 2s 267ms/step - loss: 8.2956e-04 - accuracy: 0.9832 - val_loss: 8.1864e-04 - val_accuracy: 0.9848
# Epoch 39/40
# 7/7 [==============================] - 2s 267ms/step - loss: 7.9652e-04 - accuracy: 0.9838 - val_loss: 7.9642e-04 - val_accuracy: 0.9848
# Epoch 40/40
# 7/7 [==============================] - 2s 259ms/step - loss: 7.6633e-04 - accuracy: 0.9841 - val_loss: 7.5243e-04 - val_accuracy: 0.9850

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v3/Frontal', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v3/Frontal', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([210, 60, 80, 32])

# %%
xm_train.shape[0]
# Out:
# 210

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[52  5]
#  [ 4 29]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.91      0.92        57
#          1.0       0.85      0.88      0.87        33
#
#     accuracy                           0.90        90
#    macro avg       0.89      0.90      0.89        90
# weighted avg       0.90      0.90      0.90        90

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
