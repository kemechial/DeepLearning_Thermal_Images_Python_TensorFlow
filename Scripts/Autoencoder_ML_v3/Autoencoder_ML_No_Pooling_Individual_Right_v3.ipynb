# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.10.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Right.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (208, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 7/7 [==============================] - 59s 7s/step - loss: 0.1909 - accuracy: 0.4010 - val_loss: 0.1751 - val_accuracy: 0.4360
# Epoch 2/40
# 7/7 [==============================] - 2s 282ms/step - loss: 0.1651 - accuracy: 0.4390 - val_loss: 0.1326 - val_accuracy: 0.4441
# Epoch 3/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1293 - accuracy: 0.4555 - val_loss: 0.1088 - val_accuracy: 0.4652
# Epoch 4/40
# 7/7 [==============================] - 2s 284ms/step - loss: 0.1028 - accuracy: 0.4636 - val_loss: 0.0877 - val_accuracy: 0.4703
# Epoch 5/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0843 - accuracy: 0.4694 - val_loss: 0.0727 - val_accuracy: 0.4668
# Epoch 6/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0688 - accuracy: 0.4757 - val_loss: 0.0559 - val_accuracy: 0.4820
# Epoch 7/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0518 - accuracy: 0.4959 - val_loss: 0.0408 - val_accuracy: 0.4940
# Epoch 8/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0385 - accuracy: 0.5021 - val_loss: 0.0320 - val_accuracy: 0.4884
# Epoch 9/40
# 7/7 [==============================] - 2s 322ms/step - loss: 0.0315 - accuracy: 0.4953 - val_loss: 0.0277 - val_accuracy: 0.4905
# Epoch 10/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0279 - accuracy: 0.5031 - val_loss: 0.0255 - val_accuracy: 0.4947
# Epoch 11/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0260 - accuracy: 0.5008 - val_loss: 0.0241 - val_accuracy: 0.4938
# Epoch 12/40
# 7/7 [==============================] - 2s 286ms/step - loss: 0.0247 - accuracy: 0.5079 - val_loss: 0.0230 - val_accuracy: 0.5138
# Epoch 13/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0234 - accuracy: 0.5437 - val_loss: 0.0216 - val_accuracy: 0.5964
# Epoch 14/40
# 7/7 [==============================] - 2s 284ms/step - loss: 0.0218 - accuracy: 0.6342 - val_loss: 0.0195 - val_accuracy: 0.6734
# Epoch 15/40
# 7/7 [==============================] - 2s 286ms/step - loss: 0.0193 - accuracy: 0.7202 - val_loss: 0.0170 - val_accuracy: 0.7920
# Epoch 16/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0168 - accuracy: 0.8084 - val_loss: 0.0148 - val_accuracy: 0.8420
# Epoch 17/40
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0147 - accuracy: 0.8629 - val_loss: 0.0128 - val_accuracy: 0.9013
# Epoch 18/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0127 - accuracy: 0.9205 - val_loss: 0.0111 - val_accuracy: 0.9499
# Epoch 19/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0109 - accuracy: 0.9596 - val_loss: 0.0094 - val_accuracy: 0.9627
# Epoch 20/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0092 - accuracy: 0.9676 - val_loss: 0.0079 - val_accuracy: 0.9684
# Epoch 21/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0076 - accuracy: 0.9715 - val_loss: 0.0064 - val_accuracy: 0.9724
# Epoch 22/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0061 - accuracy: 0.9739 - val_loss: 0.0050 - val_accuracy: 0.9744
# Epoch 23/40
# 7/7 [==============================] - 2s 285ms/step - loss: 0.0047 - accuracy: 0.9765 - val_loss: 0.0038 - val_accuracy: 0.9754
# Epoch 24/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0035 - accuracy: 0.9770 - val_loss: 0.0029 - val_accuracy: 0.9766
# Epoch 25/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0027 - accuracy: 0.9774 - val_loss: 0.0022 - val_accuracy: 0.9748
# Epoch 26/40
# 7/7 [==============================] - 2s 284ms/step - loss: 0.0021 - accuracy: 0.9767 - val_loss: 0.0018 - val_accuracy: 0.9762
# Epoch 27/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0017 - accuracy: 0.9771 - val_loss: 0.0015 - val_accuracy: 0.9773
# Epoch 28/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0015 - accuracy: 0.9785 - val_loss: 0.0013 - val_accuracy: 0.9789
# Epoch 29/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0012 - accuracy: 0.9796 - val_loss: 0.0011 - val_accuracy: 0.9797
# Epoch 30/40
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0011 - accuracy: 0.9809 - val_loss: 9.5913e-04 - val_accuracy: 0.9802
# Epoch 31/40
# 7/7 [==============================] - 2s 283ms/step - loss: 9.6255e-04 - accuracy: 0.9818 - val_loss: 8.6169e-04 - val_accuracy: 0.9820
# Epoch 32/40
# 7/7 [==============================] - 2s 275ms/step - loss: 8.6781e-04 - accuracy: 0.9827 - val_loss: 7.8457e-04 - val_accuracy: 0.9828
# Epoch 33/40
# 7/7 [==============================] - 2s 276ms/step - loss: 7.9414e-04 - accuracy: 0.9836 - val_loss: 7.2122e-04 - val_accuracy: 0.9831
# Epoch 34/40
# 7/7 [==============================] - 2s 281ms/step - loss: 7.2983e-04 - accuracy: 0.9842 - val_loss: 6.6741e-04 - val_accuracy: 0.9840
# Epoch 35/40
# 7/7 [==============================] - 2s 276ms/step - loss: 6.7760e-04 - accuracy: 0.9849 - val_loss: 6.2637e-04 - val_accuracy: 0.9849
# Epoch 36/40
# 7/7 [==============================] - 2s 344ms/step - loss: 6.3793e-04 - accuracy: 0.9856 - val_loss: 5.9198e-04 - val_accuracy: 0.9855
# Epoch 37/40
# 7/7 [==============================] - 2s 287ms/step - loss: 5.9763e-04 - accuracy: 0.9861 - val_loss: 5.5216e-04 - val_accuracy: 0.9859
# Epoch 38/40
# 7/7 [==============================] - 2s 276ms/step - loss: 5.6668e-04 - accuracy: 0.9866 - val_loss: 5.3726e-04 - val_accuracy: 0.9865
# Epoch 39/40
# 7/7 [==============================] - 2s 284ms/step - loss: 5.4041e-04 - accuracy: 0.9869 - val_loss: 5.1422e-04 - val_accuracy: 0.9865
# Epoch 40/40
# 7/7 [==============================] - 2s 281ms/step - loss: 5.1628e-04 - accuracy: 0.9871 - val_loss: 4.7973e-04 - val_accuracy: 0.9871

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v3/Right', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v3/Right', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([208, 60, 80, 32])

# %%
xm_train.shape[0]
# Out:
# 208

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[51  6]
#  [ 9 22]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.89      0.87        57
#          1.0       0.79      0.71      0.75        31
#
#     accuracy                           0.83        88
#    macro avg       0.82      0.80      0.81        88
# weighted avg       0.83      0.83      0.83        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
