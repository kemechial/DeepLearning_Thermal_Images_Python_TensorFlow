# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.10.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Left45.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (205, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 7/7 [==============================] - 58s 7s/step - loss: 0.2223 - accuracy: 0.2604 - val_loss: 0.2044 - val_accuracy: 0.2786
# Epoch 2/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.1854 - accuracy: 0.2887 - val_loss: 0.1617 - val_accuracy: 0.3055
# Epoch 3/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.1497 - accuracy: 0.3168 - val_loss: 0.1224 - val_accuracy: 0.3261
# Epoch 4/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.1091 - accuracy: 0.3679 - val_loss: 0.0918 - val_accuracy: 0.4148
# Epoch 5/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0842 - accuracy: 0.4285 - val_loss: 0.0714 - val_accuracy: 0.4531
# Epoch 6/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0646 - accuracy: 0.4640 - val_loss: 0.0549 - val_accuracy: 0.4987
# Epoch 7/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0494 - accuracy: 0.5319 - val_loss: 0.0419 - val_accuracy: 0.5715
# Epoch 8/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0382 - accuracy: 0.5818 - val_loss: 0.0337 - val_accuracy: 0.5900
# Epoch 9/40
# 7/7 [==============================] - 2s 320ms/step - loss: 0.0314 - accuracy: 0.6030 - val_loss: 0.0292 - val_accuracy: 0.6248
# Epoch 10/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0278 - accuracy: 0.6371 - val_loss: 0.0267 - val_accuracy: 0.6390
# Epoch 11/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0258 - accuracy: 0.6456 - val_loss: 0.0252 - val_accuracy: 0.6394
# Epoch 12/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0245 - accuracy: 0.6460 - val_loss: 0.0241 - val_accuracy: 0.6400
# Epoch 13/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0234 - accuracy: 0.6471 - val_loss: 0.0230 - val_accuracy: 0.6458
# Epoch 14/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0222 - accuracy: 0.6629 - val_loss: 0.0215 - val_accuracy: 0.6911
# Epoch 15/40
# 7/7 [==============================] - 2s 285ms/step - loss: 0.0206 - accuracy: 0.7258 - val_loss: 0.0197 - val_accuracy: 0.7639
# Epoch 16/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0187 - accuracy: 0.8009 - val_loss: 0.0176 - val_accuracy: 0.8386
# Epoch 17/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0163 - accuracy: 0.8615 - val_loss: 0.0148 - val_accuracy: 0.8829
# Epoch 18/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0136 - accuracy: 0.9123 - val_loss: 0.0123 - val_accuracy: 0.9564
# Epoch 19/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0113 - accuracy: 0.9654 - val_loss: 0.0103 - val_accuracy: 0.9702
# Epoch 20/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0095 - accuracy: 0.9737 - val_loss: 0.0088 - val_accuracy: 0.9728
# Epoch 21/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0082 - accuracy: 0.9758 - val_loss: 0.0076 - val_accuracy: 0.9766
# Epoch 22/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0071 - accuracy: 0.9792 - val_loss: 0.0066 - val_accuracy: 0.9782
# Epoch 23/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0061 - accuracy: 0.9794 - val_loss: 0.0057 - val_accuracy: 0.9784
# Epoch 24/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0053 - accuracy: 0.9797 - val_loss: 0.0050 - val_accuracy: 0.9791
# Epoch 25/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0047 - accuracy: 0.9806 - val_loss: 0.0043 - val_accuracy: 0.9796
# Epoch 26/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0040 - accuracy: 0.9809 - val_loss: 0.0038 - val_accuracy: 0.9792
# Epoch 27/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0035 - accuracy: 0.9812 - val_loss: 0.0033 - val_accuracy: 0.9806
# Epoch 28/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0030 - accuracy: 0.9826 - val_loss: 0.0028 - val_accuracy: 0.9816
# Epoch 29/40
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0027 - accuracy: 0.9833 - val_loss: 0.0025 - val_accuracy: 0.9819
# Epoch 30/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0023 - accuracy: 0.9838 - val_loss: 0.0022 - val_accuracy: 0.9828
# Epoch 31/40
# 7/7 [==============================] - 2s 292ms/step - loss: 0.0021 - accuracy: 0.9843 - val_loss: 0.0019 - val_accuracy: 0.9826
# Epoch 32/40
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0018 - accuracy: 0.9844 - val_loss: 0.0017 - val_accuracy: 0.9828
# Epoch 33/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0016 - accuracy: 0.9846 - val_loss: 0.0015 - val_accuracy: 0.9831
# Epoch 34/40
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0014 - accuracy: 0.9849 - val_loss: 0.0014 - val_accuracy: 0.9834
# Epoch 35/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0013 - accuracy: 0.9852 - val_loss: 0.0012 - val_accuracy: 0.9837
# Epoch 36/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0012 - accuracy: 0.9855 - val_loss: 0.0011 - val_accuracy: 0.9842
# Epoch 37/40
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0010 - accuracy: 0.9858 - val_loss: 9.9640e-04 - val_accuracy: 0.9845
# Epoch 38/40
# 7/7 [==============================] - 2s 275ms/step - loss: 9.5248e-04 - accuracy: 0.9861 - val_loss: 9.1378e-04 - val_accuracy: 0.9848
# Epoch 39/40
# 7/7 [==============================] - 2s 342ms/step - loss: 8.9343e-04 - accuracy: 0.9862 - val_loss: 8.5017e-04 - val_accuracy: 0.9850
# Epoch 40/40
# 7/7 [==============================] - 2s 277ms/step - loss: 8.3074e-04 - accuracy: 0.9865 - val_loss: 7.9526e-04 - val_accuracy: 0.9854

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Yedek/Models_Static_v3/Left45', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Yedek/Models_Static_v3/Left45', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([205, 60, 80, 32])

# %%
xm_train.shape[0]
# Out:
# 205

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[52  5]
#  [ 7 23]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.90        57
#          1.0       0.82      0.77      0.79        30
#
#     accuracy                           0.86        87
#    macro avg       0.85      0.84      0.84        87
# weighted avg       0.86      0.86      0.86        87

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
