# %%
import tensorflow as tf

import os
import tensorflow_datasets as tfds

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# !pip install hickle
import hickle as hkl
import os
import matplotlib.pyplot as plt
from keras import layers,Input,Sequential
from keras.layers import Dense,Flatten,Reshape,Conv2DTranspose,Conv2D,MaxPooling2D,Reshape,Resizing,Dropout,UpSampling2D,BatchNormalization
from tensorflow.keras import datasets, layers, models, losses, Model
from random import randint
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Collecting hickle
#   Downloading hickle-5.0.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from hickle) (3.10.0)
# Requirement already satisfied: numpy!=1.20,>=1.8 in /usr/local/lib/python3.10/dist-packages (from hickle) (1.25.2)
# Installing collected packages: hickle
# Successfully installed hickle-5.0.3
# Mounted at /gdrive
# /gdrive

# %%
load_hkl = hkl.load("/gdrive/My Drive/Yedek/Autoencoder_Datasets_v1/Static/Left.hkl")
X_train=load_hkl['xtrain'] / 255.
X_test=load_hkl['xtest'] / 255.
y_train=load_hkl['ytrain']
y_test=load_hkl['ytest']

# %%
X_train.shape
# Out:
# (206, 480, 640, 3)

# %%
class CNN_Autoencoder(Model):
    def __init__(self):
        super(CNN_Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=X_train.shape[1:]),
            layers.Conv2D(8, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')])

        self.decoder = tf.keras.Sequential([
            layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
epochs=40

# %%
with strategy.scope():
  cnn_autoencoder_front=CNN_Autoencoder()
  cnn_autoencoder_front.compile(optimizer='adam',  loss='mse',metrics=['accuracy'])
history=cnn_autoencoder_front.fit(X_train,X_train,epochs=epochs,
      batch_size=32, shuffle=True,validation_data=(X_test,X_test))
# Out:
# Epoch 1/40
# 7/7 [==============================] - 58s 7s/step - loss: 0.1888 - accuracy: 0.2867 - val_loss: 0.1705 - val_accuracy: 0.3259
# Epoch 2/40
# 7/7 [==============================] - 2s 278ms/step - loss: 0.1500 - accuracy: 0.3259 - val_loss: 0.1160 - val_accuracy: 0.3260
# Epoch 3/40
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1098 - accuracy: 0.3198 - val_loss: 0.0895 - val_accuracy: 0.3426
# Epoch 4/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0827 - accuracy: 0.3633 - val_loss: 0.0730 - val_accuracy: 0.3894
# Epoch 5/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0682 - accuracy: 0.4090 - val_loss: 0.0599 - val_accuracy: 0.4356
# Epoch 6/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0568 - accuracy: 0.4472 - val_loss: 0.0525 - val_accuracy: 0.4530
# Epoch 7/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0504 - accuracy: 0.4685 - val_loss: 0.0449 - val_accuracy: 0.4882
# Epoch 8/40
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0413 - accuracy: 0.4906 - val_loss: 0.0353 - val_accuracy: 0.4928
# Epoch 9/40
# 7/7 [==============================] - 2s 312ms/step - loss: 0.0329 - accuracy: 0.5054 - val_loss: 0.0293 - val_accuracy: 0.5027
# Epoch 10/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0283 - accuracy: 0.5116 - val_loss: 0.0266 - val_accuracy: 0.5053
# Epoch 11/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0262 - accuracy: 0.5098 - val_loss: 0.0251 - val_accuracy: 0.5034
# Epoch 12/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0249 - accuracy: 0.5080 - val_loss: 0.0240 - val_accuracy: 0.5039
# Epoch 13/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0239 - accuracy: 0.5098 - val_loss: 0.0231 - val_accuracy: 0.5080
# Epoch 14/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0229 - accuracy: 0.5156 - val_loss: 0.0222 - val_accuracy: 0.5265
# Epoch 15/40
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0219 - accuracy: 0.5489 - val_loss: 0.0211 - val_accuracy: 0.5800
# Epoch 16/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0207 - accuracy: 0.6075 - val_loss: 0.0197 - val_accuracy: 0.6665
# Epoch 17/40
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0193 - accuracy: 0.7092 - val_loss: 0.0180 - val_accuracy: 0.7623
# Epoch 18/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0174 - accuracy: 0.7990 - val_loss: 0.0159 - val_accuracy: 0.8389
# Epoch 19/40
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0153 - accuracy: 0.8717 - val_loss: 0.0140 - val_accuracy: 0.8964
# Epoch 20/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0135 - accuracy: 0.9202 - val_loss: 0.0126 - val_accuracy: 0.9502
# Epoch 21/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0122 - accuracy: 0.9669 - val_loss: 0.0114 - val_accuracy: 0.9731
# Epoch 22/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0111 - accuracy: 0.9760 - val_loss: 0.0104 - val_accuracy: 0.9761
# Epoch 23/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0103 - accuracy: 0.9783 - val_loss: 0.0097 - val_accuracy: 0.9786
# Epoch 24/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0096 - accuracy: 0.9804 - val_loss: 0.0091 - val_accuracy: 0.9803
# Epoch 25/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0090 - accuracy: 0.9813 - val_loss: 0.0086 - val_accuracy: 0.9808
# Epoch 26/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0085 - accuracy: 0.9812 - val_loss: 0.0081 - val_accuracy: 0.9803
# Epoch 27/40
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0080 - accuracy: 0.9801 - val_loss: 0.0076 - val_accuracy: 0.9771
# Epoch 28/40
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0075 - accuracy: 0.9769 - val_loss: 0.0069 - val_accuracy: 0.9738
# Epoch 29/40
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0068 - accuracy: 0.9741 - val_loss: 0.0062 - val_accuracy: 0.9727
# Epoch 30/40
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0060 - accuracy: 0.9745 - val_loss: 0.0054 - val_accuracy: 0.9760
# Epoch 31/40
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0052 - accuracy: 0.9777 - val_loss: 0.0047 - val_accuracy: 0.9788
# Epoch 32/40
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0045 - accuracy: 0.9808 - val_loss: 0.0040 - val_accuracy: 0.9812
# Epoch 33/40
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0039 - accuracy: 0.9825 - val_loss: 0.0036 - val_accuracy: 0.9822
# Epoch 34/40
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0035 - accuracy: 0.9831 - val_loss: 0.0032 - val_accuracy: 0.9827
# Epoch 35/40
# 7/7 [==============================] - 2s 285ms/step - loss: 0.0031 - accuracy: 0.9836 - val_loss: 0.0029 - val_accuracy: 0.9825
# Epoch 36/40
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0028 - accuracy: 0.9836 - val_loss: 0.0026 - val_accuracy: 0.9826
# Epoch 37/40
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0026 - accuracy: 0.9835 - val_loss: 0.0024 - val_accuracy: 0.9832
# Epoch 38/40
# 7/7 [==============================] - 2s 284ms/step - loss: 0.0023 - accuracy: 0.9837 - val_loss: 0.0021 - val_accuracy: 0.9828
# Epoch 39/40
# 7/7 [==============================] - 2s 363ms/step - loss: 0.0021 - accuracy: 0.9836 - val_loss: 0.0019 - val_accuracy: 0.9827
# Epoch 40/40
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0018 - accuracy: 0.9838 - val_loss: 0.0017 - val_accuracy: 0.9834

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
cnn_autoencoder_front.save('/gdrive/My Drive/Models_Static_v3/Left', options=save_locally)

# %%
with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    reconstructed_front = tf.keras.models.load_model('/gdrive/My Drive/Models_Static_v3/Left', options=load_locally)

# %%
xm_train=reconstructed_front.encoder(X_train)
xm_test=reconstructed_front.encoder(X_test)

# %%
xm_train.shape
# Out:
# TensorShape([206, 60, 80, 32])

# %%
xm_train.shape[0]
# Out:
# 206

# %%
xm_train=tf.reshape(xm_train,[xm_train.shape[0],-1])
xm_test=tf.reshape(xm_test,[xm_test.shape[0],-1])

# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

xm_train=scaler.fit_transform(xm_train)
xm_test=scaler.transform(xm_test)

# %%
from sklearn.svm import SVC

svc=SVC(kernel="sigmoid")
svc.fit(xm_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svc.predict(xm_test)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm=confusion_matrix(y_test, y_pred)
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# [[51  6]
#  [ 8 23]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.88        57
#          1.0       0.79      0.74      0.77        31
#
#     accuracy                           0.84        88
#    macro avg       0.83      0.82      0.82        88
# weighted avg       0.84      0.84      0.84        88

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()
